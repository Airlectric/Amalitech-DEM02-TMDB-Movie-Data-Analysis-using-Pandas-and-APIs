# %%
import sys
import importlib
import pandas as pd
sys.path.append("scripts")

from tmdb_client import fetch_popular_movies,get_movie_details, search_movie    
from analysis import movies_to_dataframe, top_movies_by_popularity, plot_top_vote_average

# %%
importlib.reload(sys.modules['tmdb_client'])
# Out:
# <module 'tmdb_client' from 'c:\\Users\\DanielAgudeyDoe\\Desktop\\Lib\\Course Projects\\Specialization\\scripts\\tmdb_client.py'>

# %%
movies = fetch_popular_movies(page=1)

# %%
print(movies['results'])
# Out:
# [{'adult': False, 'backdrop_path': '/5h2EsPKNDdB3MAtOk9MB9Ycg9Rz.jpg', 'genre_ids': [16, 10751, 35, 12, 9648], 'id': 1084242, 'original_language': 'en', 'original_title': 'Zootopia 2', 'overview': "After cracking the biggest case in Zootopia's history, rookie cops Judy Hopps and Nick Wilde find themselves on the twisting trail of a great mystery when Gary De’Snake arrives and turns the animal metropolis upside down. To crack the case, Judy and Nick must go undercover to unexpected new parts of town, where their growing partnership is tested like never before.", 'popularity': 588.0777, 'poster_path': '/oJ7g2CifqpStmoYQyaLQgEU32qO.jpg', 'release_date': '2025-11-26', 'title': 'Zootopia 2', 'video': False, 'vote_average': 7.639, 'vote_count': 238}, {'adult': False, 'backdrop_path': '/4BtL2vvEufDXDP4u6xQjjQ1Y2aT.jpg', 'genre_ids': [28, 80, 53], 'id': 1419406, 'original_language': 'zh', 'original_title': '捕风追影', 'overview': 'Macau Police brings the tracking expert police officer out of ret
# ...

# %%
df_movies = movies_to_dataframe(movies['results'])

# %%
df_movies.head()
# Out:
#    adult                     backdrop_path                  genre_ids  \
# 0  False  /5h2EsPKNDdB3MAtOk9MB9Ycg9Rz.jpg  [16, 10751, 35, 12, 9648]
# 1  False  /4BtL2vvEufDXDP4u6xQjjQ1Y2aT.jpg               [28, 80, 53]
# 2  False  /lf8IZ86ajGpgbuyHCZrXUeAMmvy.jpg              [28, 12, 878]
# 3  False  /zEsHEpCGZwGg3M2b0oSZuaPLwBh.jpg                  [878, 28]
# 4  False  /pAyImoslSnpMgjRwhaS5ZEdl8UI.jpg               [28, 53, 80]
#
#         id original_language original_title  \
# 0  1084242                en     Zootopia 2
# 1  1419406                zh           捕风追影
# 2  1033462                zh           749局
# 3  1309012                en        Altered
# 4  1448560                en        Wildcat
#
#                                             overview  popularity  \
# 0  After cracking the biggest case in Zootopia's ...    588.0777
# 1  Macau Police brings the tracking expert police...    318.0550
# 2  A traumatized young man with physical abnormal...    279.8626
# ...

# %%
zootopia_details = get_movie_details(1084242)
print(zootopia_details)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 zootopia_details = pd.DataFrame(get_movie_details(1084242))
#       2 print(zootopia_details)
#
# File c:\Users\DanielAgudeyDoe\Desktop\Lib\Course Projects\Specialization\movieenv\Lib\site-packages\pandas\core\frame.py:782, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     776     mgr = self._init_mgr(
#     777         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     778     )
#     780 elif isinstance(data, dict):
#     781     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 782     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     783 elif isinstance(data, ma.MaskedArray):
#     784     from numpy.ma import mrecords
#
# ...
