# %%
import sys
import importlib
import pandas as pd
sys.path.append("scripts")
importlib.reload(sys.modules['tmdb_client'])

from tmdb_client import fetch_popular_movies,get_movie_details, search_movie, get_all_movies_by_ids
from analysis import movies_to_dataframe, top_movies_by_popularity, plot_top_vote_average
from clean_data import drop_irrelevant_columns

# %%
movies = fetch_popular_movies(page=1)

# %%
print(movies['results'])
# Out:
# [{'adult': False, 'backdrop_path': '/5h2EsPKNDdB3MAtOk9MB9Ycg9Rz.jpg', 'genre_ids': [16, 10751, 35, 12, 9648], 'id': 1084242, 'original_language': 'en', 'original_title': 'Zootopia 2', 'overview': "After cracking the biggest case in Zootopia's history, rookie cops Judy Hopps and Nick Wilde find themselves on the twisting trail of a great mystery when Gary De’Snake arrives and turns the animal metropolis upside down. To crack the case, Judy and Nick must go undercover to unexpected new parts of town, where their growing partnership is tested like never before.", 'popularity': 588.0777, 'poster_path': '/oJ7g2CifqpStmoYQyaLQgEU32qO.jpg', 'release_date': '2025-11-26', 'title': 'Zootopia 2', 'video': False, 'vote_average': 7.639, 'vote_count': 238}, {'adult': False, 'backdrop_path': '/4BtL2vvEufDXDP4u6xQjjQ1Y2aT.jpg', 'genre_ids': [28, 80, 53], 'id': 1419406, 'original_language': 'zh', 'original_title': '捕风追影', 'overview': 'Macau Police brings the tracking expert police officer out of retirement to help catch a dangerous group of professional thieves.', 'popularity': 318.055, 'poster_path': '/e0RU6KpdnrqFxDKlI3NOqN8nHL6.jpg', 'release_date': '2025-08-16', 'title': "The Shadow's Edge", 'video': False, 'vote_average': 6.332, 'vote_count': 128}, {'adult': False, 'backdrop_path': '/lf8IZ86ajGpgbuyHCZrXUeAMmvy.jpg', 'genre_ids': [28, 12, 878], 'id': 1033462, 'original_language': 'zh', 'original_title': '749局', 'overview': 'A traumatized young man with physical abnormalities is forced to join a mysterious bureau to confront a disaster spreading across the earth caused by an unknown creature. He embarks on an adventure uncovering mysteries about his life.', 'popularity': 279.8626, 'poster_path': '/flykCMw22y6yv8vKnBjmsW3pneo.jpg', 'release_date': '2024-10-01', 'title': 'Bureau 749', 'video': False, 'vote_average': 5.911, 'vote_count': 45}, {'adult': False, 'backdrop_path': '/zEsHEpCGZwGg3M2b0oSZuaPLwBh.jpg', 'genre_ids': [878, 28], 'id': 1309012, 'original_language': 'en', 'original_title': 'Altered', 'overview': 'In an alternate present, genetically enhanced humans dominate society. Outcasts Leon and Chloe fight for justice against corrupt politicians exploiting genetic disparity, risking everything to challenge the oppressive system.', 'popularity': 240.7323, 'poster_path': '/6QlAcGRaUrgHcZ4WTBh5lsPnzKx.jpg', 'release_date': '2025-09-18', 'title': 'Altered', 'video': False, 'vote_average': 6.489, 'vote_count': 45}, {'adult': False, 'backdrop_path': '/pAyImoslSnpMgjRwhaS5ZEdl8UI.jpg', 'genre_ids': [28, 53, 80], 'id': 1448560, 'original_language': 'en', 'original_title': 'Wildcat', 'overview': 'An ex-black ops team reunite to pull off a desperate heist in order to save the life of their leader’s eight-year-old daughter.', 'popularity': 262.5736, 'poster_path': '/h893ImjM6Fsv5DFhKJdlZFZIJno.jpg', 'release_date': '2025-11-19', 'title': 'Wildcat', 'video': False, 'vote_average': 6.405, 'vote_count': 21}, {'adult': False, 'backdrop_path': '/8lqfrOBQ2EcY7znD3LxTYcvlh25.jpg', 'genre_ids': [28, 80], 'id': 949709, 'original_language': 'zh', 'original_title': '危机航线', 'overview': '"Anyone? There is ......" A mysterious message from Gao Haojun comes from ten thousand meters in the air. A five-star A380 ultra-luxury airliner was hijacked on its international maiden voyage, and international security expert Gao Haojun stood up to a group of thugs, his daughter Xiaojun was trapped in the cabin, and Mike, the leader of the hijackers, threatened the lives of more than 800 people in the plane as a bargaining chip, and Xiaojun\'s mother, Fu Yuan, was also in danger. ...... Will the passengers on board be able to land safely and how should this crisis be resolved?', 'popularity': 255.703, 'poster_path': '/v8ySgr4CE45SrrIt4PqqYc1diW6.jpg', 'release_date': '2024-09-29', 'title': 'High Forces', 'video': False, 'vote_average': 6.1, 'vote_count': 22}, {'adult': False, 'backdrop_path': '/7nAVXGHHtaNcdsqvDXmY6R9N0fG.jpg', 'genre_ids': [28, 35], 'id': 1363123, 'ori ...

# %%
df_movies = movies_to_dataframe(movies['results'])

# %%
df_movies.head()
# Out:
#    adult                     backdrop_path                  genre_ids  \
# 0  False  /5h2EsPKNDdB3MAtOk9MB9Ycg9Rz.jpg  [16, 10751, 35, 12, 9648]
# 1  False  /4BtL2vvEufDXDP4u6xQjjQ1Y2aT.jpg               [28, 80, 53]
# 2  False  /lf8IZ86ajGpgbuyHCZrXUeAMmvy.jpg              [28, 12, 878]
# 3  False  /zEsHEpCGZwGg3M2b0oSZuaPLwBh.jpg                  [878, 28]
# 4  False  /pAyImoslSnpMgjRwhaS5ZEdl8UI.jpg               [28, 53, 80]
#
#         id original_language original_title  \
# 0  1084242                en     Zootopia 2
# 1  1419406                zh           捕风追影
# 2  1033462                zh           749局
# 3  1309012                en        Altered
# 4  1448560                en        Wildcat
#
#                                             overview  popularity  \
# 0  After cracking the biggest case in Zootopia's ...    588.0777
# 1  Macau Police brings the tracking expert police...    318.0550
# 2  A traumatized young man with physical abnormal...    279.8626
# 3  In an alternate present, genetically enhanced ...    240.7323
# 4  An ex-black ops team reunite to pull off a des...    262.5736
#
#                         poster_path release_date              title  video  \
# 0  /oJ7g2CifqpStmoYQyaLQgEU32qO.jpg   2025-11-26         Zootopia 2  False
# 1  /e0RU6KpdnrqFxDKlI3NOqN8nHL6.jpg   2025-08-16  The Shadow's Edge  False
# 2  /flykCMw22y6yv8vKnBjmsW3pneo.jpg   2024-10-01         Bureau 749  False
# 3  /6QlAcGRaUrgHcZ4WTBh5lsPnzKx.jpg   2025-09-18            Altered  False
# 4  /h893ImjM6Fsv5DFhKJdlZFZIJno.jpg   2025-11-19            Wildcat  False
#
#    vote_average  vote_count
# 0         7.639         238
# 1         6.332         128
# 2         5.911          45
# 3         6.489          45
# 4         6.405          21

# %%
zootopia_details = get_movie_details(1084242)
zootopia_details = pd.DataFrame([zootopia_details])

# %%
zootopia_details
# Out:
#    adult                     backdrop_path  \
# 0  False  /5h2EsPKNDdB3MAtOk9MB9Ycg9Rz.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 1084247, 'name': 'Zootopia Collection',...  150000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
#
#                                homepage       id     imdb_id origin_country  \
# 0  https://movies.disney.com/zootopia-2  1084242  tt26443597           [US]
#
#   original_language  ... release_date    revenue  runtime  \
# 0                en  ...   2025-11-26  560333554      107
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                  tagline       title  video  vote_average  \
# 0  Zootopia will be changed furrrever...  Zootopia 2  False           7.7
#
#   vote_count
# 0        246
#
# [1 rows x 26 columns]

# %% [markdown]
# ## Fetch all movies and store in a Database

# %%
movie_ids = [0, 299534, 19995, 140607, 299536, 597, 135397, 420818, 24428, 168259, 99861, 284054, 12445, 181808, 330457, 351286, 109445, 321612, 260513]

# %%
movies = get_all_movies_by_ids(movie_ids)

# %%
movies
# Out:
# [{'success': False,
#   'status_code': 6,
#   'status_message': 'Invalid id: The pre-requisite id is invalid or not found.'},
#  {'adult': False,
#   'backdrop_path': '/9wXPKruA6bWYk2co5ix6fH59Qr8.jpg',
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'budget': 356000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'}],
#   'homepage': 'https://www.marvel.com/movies/avengers-endgame',
#   'id': 299534,
#   'imdb_id': 'tt4154796',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Avengers: Endgame',
#   'overview': "After the devastating events of Avengers: Infinity War, the universe is in ruins due to the efforts of the Mad Titan, Thanos. With the help of remaining allies, the Avengers must assemble once more in order to undo Thanos' actions and restore order to the universe once and for all, no matter what consequences may be in store.",
#   'popularity': 13.7085,
#   'poster_path': '/bR8ISy1O9XQxqiy0fQFw2BX72RQ.jpg',
#   'production_companies': [{'id': 420,
#     'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#     'name': 'Marvel Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2019-04-24',
#   'revenue': 2799439100,
#   'runtime': 181,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Japanese', 'iso_639_1': 'ja', 'name': '日本語'},
#    {'english_name': 'Xhosa', 'iso_639_1': 'xh', 'name': ''}],
#   'status': 'Released',
#   'tagline': 'Avenge the fallen.',
#   'title': 'Avengers: Endgame',
#   'video': False,
#   'vote_average': 8.238,
#   'vote_count': 26959},
#  {'adult': False,
#   'backdrop_path': '/7JNzw1tSZZEgsBw6lu0VfO2X2Ef.jpg',
#   'belongs_to_collection': {'id': 87096,
#    'name': 'Avatar Collection',
#    'poster_path': '/3C5brXxnBxfkeKWwA1Fh4xvy4wr.jpg',
#    'backdrop_path': '/6qkJLRCZp9Y3ovXti5tSuhH0DpO.jpg'},
#   'budget': 237000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.avatar.com/movies/avatar',
#   'id': 19995,
#   'imdb_id': 'tt0499549',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Avatar',
#   'overview': 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.',
#   'popularity': 24.2976,
#   'poster_path': '/gKY6q7SjCkAU6FqvqWybDYgUKIF.jpg',
#   'production_companies': [{'id': 444,
#     'logo_path': None,
#     'name': 'Dune Entertainment',
#     'origin_country': 'US'},
#    {'id': 574,
#     'logo_path': '/8wdmrfGcDx3TJxYiiDksLzAW4pB.png',
#     'name': 'Lightstorm Entertainment',
#     'origin_country': 'US'},
#    {'id': 25,
#     'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png',
#     'name': '20th Century Fox',
#     'origin_country': 'US'},
#    {'id': 133789,
#     'logo_path': '/bJdeIb1ET3BkyodAASVDq1x3mls.png',
#     'name': 'Ingenious Film Partners',
#     'origin_country': 'GB'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'},
#    {'iso_3166_1': 'GB', 'name': 'United Kingdom'}],
#   'release_date': '2009-12-15',
#   'revenue': 2923706026,
#   'runtime': 162,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Spanish', 'iso_639_1': 'es', 'name': 'Español'}],
#   'status': 'Released',
#   'tagline': 'Enter the world of Pandora.',
#   'title': 'Avatar',
#   'video': False,
#   'vote_average': 7.594,
#   'vote_count': 32853},
#  {'adult': False,
#   'backdrop_path': '/8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg',
#   'belongs_to_collection': {'id': 10,
#    'name': 'Star Wars Collection',
#    'poster_path': '/22dj38IckjzEEUZwN1tPU5VJ1qq.jpg',
#    'backdrop_path': '/4z9ijhgEthfRHShoOvMaBlpciXS.jpg'},
#   'budget': 245000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'http://www.starwars.com/films/star-wars-episode-vii',
#   'id': 140607,
#   'imdb_id': 'tt2488496',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Star Wars: The Force Awakens',
#   'overview': 'Thirty years after defeating the Galactic Empire, Han Solo and his allies face a new threat from the evil Kylo Ren and his army of Stormtroopers.',
#   'popularity': 7.8068,
#   'poster_path': '/wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg',
#   'production_companies': [{'id': 1,
#     'logo_path': '/tlVSws0RvvtPBwViUyOFAO0vcQS.png',
#     'name': 'Lucasfilm Ltd.',
#     'origin_country': 'US'},
#    {'id': 11461,
#     'logo_path': '/p9FoEt5shEKRWRKVIlvFaEmRnun.png',
#     'name': 'Bad Robot',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2015-12-15',
#   'revenue': 2068223624,
#   'runtime': 136,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Every generation has a story.',
#   'title': 'Star Wars: The Force Awakens',
#   'video': False,
#   'vote_average': 7.3,
#   'vote_count': 20103},
#  {'adult': False,
#   'backdrop_path': '/mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg',
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'budget': 300000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.marvel.com/movies/avengers-infinity-war',
#   'id': 299536,
#   'imdb_id': 'tt4154756',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Avengers: Infinity War',
#   'overview': 'As the Avengers and their allies have continued to protect the world from threats too large for any one hero to handle, a new danger has emerged from the cosmic shadows: Thanos. A despot of intergalactic infamy, his goal is to collect all six Infinity Stones, artifacts of unimaginable power, and use them to inflict his twisted will on all of reality. Everything the Avengers have fought for has led up to this moment - the fate of Earth and existence itself has never been more uncertain.',
#   'popularity': 22.2327,
#   'poster_path': '/7WsyChQLEftFiDOVTGkv3hFpyyt.jpg',
#   'production_companies': [{'id': 420,
#     'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#     'name': 'Marvel Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2018-04-25',
#   'revenue': 2052415039,
#   'runtime': 149,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Xhosa', 'iso_639_1': 'xh', 'name': ''}],
#   'status': 'Released',
#   'tagline': 'Destiny arrives all the same.',
#   'title': 'Avengers: Infinity War',
#   'video': False,
#   'vote_average': 8.236,
#   'vote_count': 31176},
#  {'adult': False,
#   'backdrop_path': '/xnHVX37XZEp33hhCbYlQFq7ux1J.jpg',
#   'belongs_to_collection': None,
#   'budget': 200000000,
#   'genres': [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}],
#   'homepage': 'https://www.paramountmovies.com/movies/titanic',
#   'id': 597,
#   'imdb_id': 'tt0120338',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Titanic',
#   'overview': "101-year-old Rose DeWitt Bukater tells the story of her life aboard the Titanic, 84 years later. A young Rose boards the ship with her mother and fiancé. Meanwhile, Jack Dawson and Fabrizio De Rossi win third-class tickets aboard the ship. Rose tells the whole story from Titanic's departure through to its death—on its first and last voyage—on April 15, 1912.",
#   'popularity': 28.7753,
#   'poster_path': '/9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg',
#   'production_companies': [{'id': 4,
#     'logo_path': '/jay6WcMgagAklUt7i9Euwj1pzTF.png',
#     'name': 'Paramount Pictures',
#     'origin_country': 'US'},
#    {'id': 25,
#     'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png',
#     'name': '20th Century Fox',
#     'origin_country': 'US'},
#    {'id': 574,
#     'logo_path': '/8wdmrfGcDx3TJxYiiDksLzAW4pB.png',
#     'name': 'Lightstorm Entertainment',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '1997-11-18',
#   'revenue': 2264162353,
#   'runtime': 194,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'French', 'iso_639_1': 'fr', 'name': 'Français'},
#    {'english_name': 'German', 'iso_639_1': 'de', 'name': 'Deutsch'},
#    {'english_name': 'Swedish', 'iso_639_1': 'sv', 'name': 'svenska'},
#    {'english_name': 'Italian', 'iso_639_1': 'it', 'name': 'Italiano'},
#    {'english_name': 'Russian', 'iso_639_1': 'ru', 'name': 'Pусский'}],
#   'status': 'Released',
#   'tagline': 'Nothing on earth could come between them.',
#   'title': 'Titanic',
#   'video': False,
#   'vote_average': 7.903,
#   'vote_count': 26511},
#  {'adult': False,
#   'backdrop_path': '/dF6FjTZzRTENfB4R17HDN20jLT2.jpg',
#   'belongs_to_collection': {'id': 328,
#    'name': 'Jurassic Park Collection',
#    'poster_path': '/qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg',
#    'backdrop_path': '/njFixYzIxX8jsn6KMSEtAzi4avi.jpg'},
#   'budget': 150000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://www.jurassicworld.com/',
#   'id': 135397,
#   'imdb_id': 'tt0369610',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Jurassic World',
#   'overview': 'Twenty-two years after the events of Jurassic Park, Isla Nublar now features a fully functioning dinosaur theme park, Jurassic World, as originally envisioned by John Hammond.',
#   'popularity': 9.5096,
#   'poster_path': '/rhr4y79GpxQF9IsfJItRXVaoGs4.jpg',
#   'production_companies': [{'id': 56,
#     'logo_path': '/cEaxANEisCqeEoRvODv2dO1I0iI.png',
#     'name': 'Amblin Entertainment',
#     'origin_country': 'US'},
#    {'id': 33,
#     'logo_path': '/6exxhPonOo0M995SAchY0ijpRao.png',
#     'name': 'Universal Pictures',
#     'origin_country': 'US'},
#    {'id': 923,
#     'logo_path': '/5UQsZrfbfG2dYJbx8DxfoTr2Bvu.png',
#     'name': 'Legendary Pictures',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2015-06-06',
#   'revenue': 1671537444,
#   'runtime': 124,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'The park is open.',
#   'title': 'Jurassic World',
#   'video': False,
#   'vote_average': 6.7,
#   'vote_count': 21120},
#  {'adult': False,
#   'backdrop_path': '/1TUg5pO1VZ4B0Q1amk3OlXvlpXV.jpg',
#   'belongs_to_collection': {'id': 762512,
#    'name': 'The Lion King (Reboot) Collection',
#    'poster_path': '/dGpIRn4Nqi63JO1RlKxjcPbQSAw.jpg',
#    'backdrop_path': '/1KeXF239BkqLChcAcF8gKl1stZz.jpg'},
#   'budget': 260000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 16, 'name': 'Animation'}],
#   'homepage': 'https://movies.disney.com/the-lion-king-2019',
#   'id': 420818,
#   'imdb_id': 'tt6105098',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'The Lion King',
#   'overview': "Simba idolizes his father, King Mufasa, and takes to heart his own royal destiny. But not everyone in the kingdom celebrates the new cub's arrival. Scar, Mufasa's brother—and former heir to the throne—has plans of his own. The battle for Pride Rock is ravaged with betrayal, tragedy and drama, ultimately resulting in Simba's exile. With help from a curious pair of newfound friends, Simba will have to figure out how to grow up and take back what is rightfully his.",
#   'popularity': 9.0748,
#   'poster_path': '/dzBtMocZuJbjLOXvrl4zGYigDzh.jpg',
#   'production_companies': [{'id': 2,
#     'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png',
#     'name': 'Walt Disney Pictures',
#     'origin_country': 'US'},
#    {'id': 7297,
#     'logo_path': '/l29JYQVZbTcjZXoz4CUYFpKRmM3.png',
#     'name': 'Fairview Entertainment',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2019-07-12',
#   'revenue': 1662020819,
#   'runtime': 118,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'The king has returned.',
#   'title': 'The Lion King',
#   'video': False,
#   'vote_average': 7.103,
#   'vote_count': 10569},
#  {'adult': False,
#   'backdrop_path': '/9BBTo63ANSmhC4e6r62OJFuK2GL.jpg',
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'budget': 220000000,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'}],
#   'homepage': 'https://www.marvel.com/movies/the-avengers',
#   'id': 24428,
#   'imdb_id': 'tt0848228',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'The Avengers',
#   'overview': 'When an unexpected enemy emerges and threatens global safety and security, Nick Fury, director of the international peacekeeping agency known as S.H.I.E.L.D., finds himself in need of a team to pull the world back from the brink of disaster. Spanning the globe, a daring recruitment effort begins!',
#   'popularity': 45.5917,
#   'poster_path': '/RYMX2wcKCBAr24UyPD7xwmjaTn.jpg',
#   'production_companies': [{'id': 420,
#     'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#     'name': 'Marvel Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2012-04-25',
#   'revenue': 1518815515,
#   'runtime': 143,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Hindi', 'iso_639_1': 'hi', 'name': 'हिन्दी'},
#    {'english_name': 'Russian', 'iso_639_1': 'ru', 'name': 'Pусский'}],
#   'status': 'Released',
#   'tagline': 'Some assembly required.',
#   'title': 'The Avengers',
#   'video': False,
#   'vote_average': 7.864,
#   'vote_count': 34211},
#  {'adult': False,
#   'backdrop_path': '/ehzI1mVcnHqB58NqPyQwpMqcVoz.jpg',
#   'belongs_to_collection': {'id': 9485,
#    'name': 'The Fast and the Furious Collection',
#    'poster_path': '/zOCnMPoUxgJK1RFPfN4PcnT16gr.jpg',
#    'backdrop_path': '/z5A5W3WYJc3UVEWljSGwdjDgQ0j.jpg'},
#   'budget': 190000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 80, 'name': 'Crime'},
#    {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://www.uphe.com/movies/furious-7',
#   'id': 168259,
#   'imdb_id': 'tt2820852',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Furious 7',
#   'overview': 'Deckard Shaw seeks revenge against Dominic Toretto and his family for his comatose brother.',
#   'popularity': 8.675,
#   'poster_path': '/ktofZ9Htrjiy0P6LEowsDaxd3Ri.jpg',
#   'production_companies': [{'id': 333,
#     'logo_path': '/5xUJfzPZ8jWJUDzYtIeuPO4qPIa.png',
#     'name': 'Original Film',
#     'origin_country': 'US'},
#    {'id': 1225,
#     'logo_path': '/rIxhJMR7oK8b2fMakmTfRLY2TZv.png',
#     'name': 'One Race',
#     'origin_country': 'US'},
#    {'id': 33,
#     'logo_path': '/6exxhPonOo0M995SAchY0ijpRao.png',
#     'name': 'Universal Pictures',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2015-04-01',
#   'revenue': 1515400000,
#   'runtime': 139,
#   'spoken_languages': [{'english_name': 'Arabic',
#     'iso_639_1': 'ar',
#     'name': 'العربية'},
#    {'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'},
#    {'english_name': 'Spanish', 'iso_639_1': 'es', 'name': 'Español'},
#    {'english_name': 'Thai', 'iso_639_1': 'th', 'name': 'ภาษาไทย'}],
#   'status': 'Released',
#   'tagline': 'Vengeance hits home.',
#   'title': 'Furious 7',
#   'video': False,
#   'vote_average': 7.223,
#   'vote_count': 11029},
#  {'adult': False,
#   'backdrop_path': '/kIBK5SKwgqIIuRKhhWrJn3XkbPq.jpg',
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'budget': 235000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.marvel.com/movies/avengers-age-of-ultron',
#   'id': 99861,
#   'imdb_id': 'tt2395427',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Avengers: Age of Ultron',
#   'overview': 'When Tony Stark tries to jumpstart a dormant peacekeeping program, things go awry and Earth’s Mightiest Heroes are put to the ultimate test as the fate of the planet hangs in the balance. As the villainous Ultron emerges, it is up to The Avengers to stop him from enacting his terrible plans, and soon uneasy alliances and unexpected action pave the way for an epic and unique global adventure.',
#   'popularity': 10.5454,
#   'poster_path': '/4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg',
#   'production_companies': [{'id': 420,
#     'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#     'name': 'Marvel Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2015-04-22',
#   'revenue': 1405403694,
#   'runtime': 141,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'A new age has come.',
#   'title': 'Avengers: Age of Ultron',
#   'video': False,
#   'vote_average': 7.3,
#   'vote_count': 23875},
#  {'adult': False,
#   'backdrop_path': '/b6ZJZHUdMEFECvGiDpJjlfUWela.jpg',
#   'belongs_to_collection': {'id': 529892,
#    'name': 'Black Panther Collection',
#    'poster_path': '/VtMkk2s92SnDUt8eYyUyYaSJQK.jpg',
#    'backdrop_path': '/nsiBzWsmmerBMuD8TKHpYBTnfhD.jpg'},
#   'budget': 200000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.marvel.com/movies/black-panther',
#   'id': 284054,
#   'imdb_id': 'tt1825683',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Black Panther',
#   'overview': "King T'Challa returns home to the reclusive, technologically advanced African nation of Wakanda to serve as his country's new leader. However, T'Challa soon finds that he is challenged for the throne by factions within his own country as well as without. Using powers reserved to Wakandan kings, T'Challa assumes the Black Panther mantle to join with ex-girlfriend Nakia, the queen-mother, his princess-kid sister, members of the Dora Milaje (the Wakandan 'special forces') and an American secret agent, to prevent Wakanda from being dragged into a world war.",
#   'popularity': 8.6974,
#   'poster_path': '/uxzzxijgPIY7slzFvMotPv8wjKA.jpg',
#   'production_companies': [{'id': 420,
#     'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#     'name': 'Marvel Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2018-02-13',
#   'revenue': 1349926083,
#   'runtime': 135,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Korean', 'iso_639_1': 'ko', 'name': '한국어/조선말'},
#    {'english_name': 'Swahili', 'iso_639_1': 'sw', 'name': 'Kiswahili'},
#    {'english_name': 'Xhosa', 'iso_639_1': 'xh', 'name': ''}],
#   'status': 'Released',
#   'tagline': 'Long live the king.',
#   'title': 'Black Panther',
#   'video': False,
#   'vote_average': 7.366,
#   'vote_count': 22968},
#  {'adult': False,
#   'backdrop_path': '/n5A7brJCjejceZmHyujwUTVgQNC.jpg',
#   'belongs_to_collection': {'id': 1241,
#    'name': 'Harry Potter Collection',
#    'poster_path': '/eVPs2Y0LyvTLZn6AP5Z6O2rtiGB.jpg',
#    'backdrop_path': '/kmEsQL2vOTA0jnM28fXS45Ky8kX.jpg'},
#   'budget': 125000000,
#   'genres': [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}],
#   'homepage': 'https://www.warnerbros.com/movies/harry-potter-and-deathly-hallows-part-2',
#   'id': 12445,
#   'imdb_id': 'tt1201607',
#   'origin_country': ['GB'],
#   'original_language': 'en',
#   'original_title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'overview': "Harry, Ron and Hermione continue their quest to vanquish the evil Voldemort once and for all. Just as things begin to look hopeless for the young wizards, Harry discovers a trio of magical objects that endow him with powers to rival Voldemort's formidable skills.",
#   'popularity': 16.6485,
#   'poster_path': '/c54HpQmuwXjHq2C9wmoACjxoom3.jpg',
#   'production_companies': [{'id': 174,
#     'logo_path': '/ingPVoHnINIrFR7WHmYux1f5pES.png',
#     'name': 'Warner Bros. Pictures',
#     'origin_country': 'US'},
#    {'id': 437,
#     'logo_path': '/nu20mtwbEIhUNnQ5NXVhHsNknZj.png',
#     'name': 'Heyday Films',
#     'origin_country': 'GB'}],
#   'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   'release_date': '2011-07-12',
#   'revenue': 1341511219,
#   'runtime': 130,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'It all ends.',
#   'title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'video': False,
#   'vote_average': 8.084,
#   'vote_count': 21450},
#  {'adult': False,
#   'backdrop_path': '/5Iw7zQTHVRBOYpA0V6z0yypOPZh.jpg',
#   'belongs_to_collection': {'id': 10,
#    'name': 'Star Wars Collection',
#    'poster_path': '/22dj38IckjzEEUZwN1tPU5VJ1qq.jpg',
#    'backdrop_path': '/4z9ijhgEthfRHShoOvMaBlpciXS.jpg'},
#   'budget': 300000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.starwars.com/films/star-wars-episode-viii-the-last-jedi',
#   'id': 181808,
#   'imdb_id': 'tt2527336',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Star Wars: The Last Jedi',
#   'overview': 'Rey develops her newly discovered abilities with the guidance of Luke Skywalker, who is unsettled by the strength of her powers. Meanwhile, the Resistance prepares to do battle with the First Order.',
#   'popularity': 6.9144,
#   'poster_path': '/kOVEVeg59E0wsnXmF9nrh6OmWII.jpg',
#   'production_companies': [{'id': 1,
#     'logo_path': '/tlVSws0RvvtPBwViUyOFAO0vcQS.png',
#     'name': 'Lucasfilm Ltd.',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2017-12-13',
#   'revenue': 1332698830,
#   'runtime': 152,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Let the Past Die',
#   'title': 'Star Wars: The Last Jedi',
#   'video': False,
#   'vote_average': 6.8,
#   'vote_count': 15926},
#  {'adult': False,
#   'backdrop_path': '/AoSZyb37ljMAxw0RdeQEBHKtgcc.jpg',
#   'belongs_to_collection': {'id': 386382,
#    'name': 'Frozen Collection',
#    'poster_path': '/13Op41T3cALJedrKqYPrlc3cIbO.jpg',
#    'backdrop_path': '/s3vdRkK7KZFUDC8HEJo2GRKyVhW.jpg'},
#   'budget': 150000000,
#   'genres': [{'id': 10751, 'name': 'Family'},
#    {'id': 16, 'name': 'Animation'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 35, 'name': 'Comedy'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'homepage': 'https://movies.disney.com/frozen-2',
#   'id': 330457,
#   'imdb_id': 'tt4520988',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Frozen II',
#   'overview': 'Elsa, Anna, Kristoff and Olaf head far into the forest to learn the truth about an ancient mystery of their kingdom.',
#   'popularity': 10.0343,
#   'poster_path': '/mINJaa34MtknCYl5AjtNJzWj8cD.jpg',
#   'production_companies': [{'id': 6125,
#     'logo_path': '/tzsMJBJZINu7GHzrpYzpReWhh66.png',
#     'name': 'Walt Disney Animation Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2019-11-20',
#   'revenue': 1453683476,
#   'runtime': 103,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'The past is not what it seems.',
#   'title': 'Frozen II',
#   'video': False,
#   'vote_average': 7.241,
#   'vote_count': 10071},
#  {'adult': False,
#   'backdrop_path': '/gBmrsugfWpiXRh13Vo3j0WW55qD.jpg',
#   'belongs_to_collection': {'id': 328,
#    'name': 'Jurassic Park Collection',
#    'poster_path': '/qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg',
#    'backdrop_path': '/njFixYzIxX8jsn6KMSEtAzi4avi.jpg'},
#   'budget': 170000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://www.uphe.com/movies/jurassic-world-fallen-kingdom',
#   'id': 351286,
#   'imdb_id': 'tt4881806',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Jurassic World: Fallen Kingdom',
#   'overview': "Three years after Jurassic World was destroyed, Isla Nublar now sits abandoned. When the island's dormant volcano begins roaring to life, Owen and Claire mount a campaign to rescue the remaining dinosaurs from this extinction-level event.",
#   'popularity': 9.2901,
#   'poster_path': '/x8cLgs0uXlb9rmpuVIxopoRGnCr.jpg',
#   'production_companies': [{'id': 56,
#     'logo_path': '/cEaxANEisCqeEoRvODv2dO1I0iI.png',
#     'name': 'Amblin Entertainment',
#     'origin_country': 'US'},
#    {'id': 33,
#     'logo_path': '/6exxhPonOo0M995SAchY0ijpRao.png',
#     'name': 'Universal Pictures',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2018-06-06',
#   'revenue': 1310469037,
#   'runtime': 129,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Russian', 'iso_639_1': 'ru', 'name': 'Pусский'}],
#   'status': 'Released',
#   'tagline': 'The park is gone.',
#   'title': 'Jurassic World: Fallen Kingdom',
#   'video': False,
#   'vote_average': 6.538,
#   'vote_count': 12408},
#  {'adult': False,
#   'backdrop_path': '/u2bZhH3nTf0So0UIC1QxAqBvC07.jpg',
#   'belongs_to_collection': {'id': 386382,
#    'name': 'Frozen Collection',
#    'poster_path': '/13Op41T3cALJedrKqYPrlc3cIbO.jpg',
#    'backdrop_path': '/s3vdRkK7KZFUDC8HEJo2GRKyVhW.jpg'},
#   'budget': 150000000,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'homepage': 'http://movies.disney.com/frozen',
#   'id': 109445,
#   'imdb_id': 'tt2294629',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Frozen',
#   'overview': "Young princess Anna of Arendelle dreams about finding true love at her sister Elsa’s coronation. Fate takes her on a dangerous journey in an attempt to end the eternal winter that has fallen over the kingdom. She's accompanied by ice delivery man Kristoff, his reindeer Sven, and snowman Olaf. On an adventure where she will find out what friendship, courage, family, and true love really means.",
#   'popularity': 20.426,
#   'poster_path': '/itAKcobTYGpYT8Phwjd8c9hleTo.jpg',
#   'production_companies': [{'id': 6125,
#     'logo_path': '/tzsMJBJZINu7GHzrpYzpReWhh66.png',
#     'name': 'Walt Disney Animation Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2013-11-20',
#   'revenue': 1274219009,
#   'runtime': 102,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Who will save the day? The ice guy? The nice guy? The snow man? Or no man?',
#   'title': 'Frozen',
#   'video': False,
#   'vote_average': 7.249,
#   'vote_count': 17182},
#  {'adult': False,
#   'backdrop_path': '/uU1Mt4JWhDvl4vKb3AfxNsorkoM.jpg',
#   'belongs_to_collection': None,
#   'budget': 160000000,
#   'genres': [{'id': 10751, 'name': 'Family'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 10749, 'name': 'Romance'}],
#   'homepage': 'http://movies.disney.com/beauty-and-the-beast-2017',
#   'id': 321612,
#   'imdb_id': 'tt2771200',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Beauty and the Beast',
#   'overview': "A live-action adaptation of Disney's version of the classic tale of a cursed prince and a beautiful young woman who helps him break the spell.",
#   'popularity': 11.9931,
#   'poster_path': '/hKegSKIDep2ewJWPUQD7u0KqFIp.jpg',
#   'production_companies': [{'id': 2,
#     'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png',
#     'name': 'Walt Disney Pictures',
#     'origin_country': 'US'},
#    {'id': 10227,
#     'logo_path': '/3YfRy3DBl4abcqkzGx4RVNz12yl.png',
#     'name': 'Mandeville Films',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2017-03-16',
#   'revenue': 1266115964,
#   'runtime': 129,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'French', 'iso_639_1': 'fr', 'name': 'Français'}],
#   'status': 'Released',
#   'tagline': 'Be our guest.',
#   'title': 'Beauty and the Beast',
#   'video': False,
#   'vote_average': 6.969,
#   'vote_count': 15831},
#  {'adult': False,
#   'backdrop_path': '/mabuNsGJgRuCTuGqjFkWe1xdu19.jpg',
#   'belongs_to_collection': {'id': 468222,
#    'name': 'The Incredibles Collection',
#    'poster_path': '/iOz4Zz72JIqkuTXSnbvNoloA6oD.jpg',
#    'backdrop_path': '/6oi6V1O9MJRNnfV8E9JMntmFqBD.jpg'},
#   'budget': 200000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'}],
#   'homepage': 'https://movies.disney.com/incredibles-2',
#   'id': 260513,
#   'imdb_id': 'tt3606756',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Incredibles 2',
#   'overview': 'Elastigirl springs into action to save the day, while Mr. Incredible faces his greatest challenge yet – taking care of the problems of his three children.',
#   'popularity': 10.7522,
#   'poster_path': '/9lFKBtaVIhP7E2Pk0IY1CwTKTMZ.jpg',
#   'production_companies': [{'id': 3,
#     'logo_path': '/1TjvGVDMYsj6JBxOAkUHpPEwLf7.png',
#     'name': 'Pixar',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2018-06-14',
#   'revenue': 1243225667,
#   'runtime': 118,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': "It's been too long, dahlings.",
#   'title': 'Incredibles 2',
#   'video': False,
#   'vote_average': 7.456,
#   'vote_count': 13366}]

# %%
df = movies_to_dataframe(movies['results'])

# %%
df
# Out:
#     adult                     backdrop_path                  genre_ids  \
# 0   False  /5h2EsPKNDdB3MAtOk9MB9Ycg9Rz.jpg  [16, 10751, 35, 12, 9648]
# 1   False  /4BtL2vvEufDXDP4u6xQjjQ1Y2aT.jpg               [28, 80, 53]
# 2   False  /lf8IZ86ajGpgbuyHCZrXUeAMmvy.jpg              [28, 12, 878]
# 3   False  /zEsHEpCGZwGg3M2b0oSZuaPLwBh.jpg                  [878, 28]
# 4   False  /pAyImoslSnpMgjRwhaS5ZEdl8UI.jpg               [28, 53, 80]
# 5   False  /8lqfrOBQ2EcY7znD3LxTYcvlh25.jpg                   [28, 80]
# 6   False  /7nAVXGHHtaNcdsqvDXmY6R9N0fG.jpg                   [28, 35]
# 7   False  /nt0HRxlzOXRpPJtl2FmeBCO6MeR.jpg            [27, 14, 10749]
# 8   False  /ytCi1wg6YHpYcFRWCO2jpzN31Kf.jpg               [28, 53, 80]
# 9   False  /tRdorrIjlybrGsebXOzgF7vRyYy.jpg                   [28, 53]
# 10  False  /l8pwO23MCvqYumzozpxynCNfck1.jpg            [14, 12, 10749]
# 11  False  /hpXBJxLD2SEf8l2CspmSeiHrBKX.jpg               [18, 14, 27]
# 12  False  /7hDFhV4ng4cHgSnxvO0MIb11Sbp.jpg              [28, 878, 12]
# 13  False  /iZLqwEwUViJdSkGVjePGhxYzbDb.jpg                  [878, 53]
# 14  False  /g3lCbTn3HYHTiFrfusxKGXMdyUW.jpg              [878, 12, 28]
# 15  False  /cVzAhirOhKh91AB1TFcGn0Rh5c3.jpg                   [28, 53]
# 16  False  /lZYMXx74pWmbj5Q5jp1QaMvmuuR.jpg               [28, 14, 53]
# 17  False  /eMBYlgFTHfZaTz96eJxlkeMsKo9.jpg                   [16, 28]
# 18  False  /7FDVhmCur4LMOfnXMteiSCtsdOb.jpg               [28, 12, 14]
# 19  False  /kyp7PSCKPZKGosthRbjfXPm8gJg.jpg               [53, 80, 28]
#
#          id original_language                    original_title  \
# 0   1084242                en                        Zootopia 2
# 1   1419406                zh                              捕风追影
# 2   1033462                zh                              749局
# 3   1309012                en                           Altered
# 4   1448560                en                           Wildcat
# 5    949709                zh                              危机航线
# 6   1363123                en                 The Family Plan 2
# 7   1246049                fr                           Dracula
# 8   1196573                en                 She Rides Shotgun
# 9   1469354                en                    Border Hunters
# 10   967941                en                  Wicked: For Good
# 11  1062722                en                      Frankenstein
# 12  1242898                en                Predator: Badlands
# 13   755898                en                 War of the Worlds
# 14   533533                en                        TRON: Ares
# 15  1208561                en                Art of Eight Limbs
# 16  1180831                no                           Troll 2
# 17  1539104                ja  劇場版 呪術廻戦「渋谷事変 特別編集版」×「死滅回游 先行上映」
# 18  1116465                zh                                传说
# 19  1433719                en                       High Ground
#
#                                              overview  popularity  \
# 0   After cracking the biggest case in Zootopia's ...    588.0777
# 1   Macau Police brings the tracking expert police...    318.0550
# 2   A traumatized young man with physical abnormal...    279.8626
# 3   In an alternate present, genetically enhanced ...    240.7323
# 4   An ex-black ops team reunite to pull off a des...    262.5736
# 5   "Anyone? There is ......" A mysterious message...    255.7030
# 6   Now that Dan's assassin days are behind him, a...    197.1049
# 7   When a 15th-century prince denounces God after...    234.4226
# 8   Newly released from prison and marked for deat...    201.1906
# 9   After his police officer brother is killed by ...    198.1722
# 10  As an angry mob rises against the Wicked Witch...    196.1270
# 11  Dr. Victor Frankenstein, a brilliant but egoti...    166.9899
# 12  Cast out from his clan, a young Predator finds...    186.7735
# 13  Will Radford is a top analyst for Homeland Sec...    154.2379
# 14  A highly sophisticated Program called Ares is ...    172.1827
# 15  Four canisters of deadly VX nerve gas have fal...    172.8399
# 16  When a dangerous new troll unleashes devastati...    161.9837
# 17  A veil abruptly descends over the busy Shibuya...    134.9268
# 18  An archeologist noticed that the texture of th...    124.5523
# 19  When a mysterious prisoner lands in jail, a bo...    103.5229
#
#                          poster_path release_date  \
# 0   /oJ7g2CifqpStmoYQyaLQgEU32qO.jpg   2025-11-26
# 1   /e0RU6KpdnrqFxDKlI3NOqN8nHL6.jpg   2025-08-16
# 2   /flykCMw22y6yv8vKnBjmsW3pneo.jpg   2024-10-01
# 3   /6QlAcGRaUrgHcZ4WTBh5lsPnzKx.jpg   2025-09-18
# 4   /h893ImjM6Fsv5DFhKJdlZFZIJno.jpg   2025-11-19
# 5   /v8ySgr4CE45SrrIt4PqqYc1diW6.jpg   2024-09-29
# 6   /semFxuYx6HcrkZzslgAkBqfJvZk.jpg   2025-11-11
# 7   /ykyRfv7JDofLxXLAwtLXaSuaFfM.jpg   2025-07-30
# 8   /nvqW8mOm818QDio3GKKmPLK8kXj.jpg   2025-07-31
# 9   /6TNFZnJ5CU0uFQxGaO9dbqriiI7.jpg   2025-10-20
# 10  /si9tolnefLSUKaqQEGz1bWArOaL.jpg   2025-11-19
# 11  /g4JtvGlQO7DByTI6frUobqvSL3R.jpg   2025-10-17
# 12  /ef2QSeBkrYhAdfsWGXmp0lvH0T1.jpg   2025-11-05
# 13  /yvirUYrva23IudARHn3mMGVxWqM.jpg   2025-07-29
# 14  /chpWmskl3aKm1aTZqUHRCtviwPy.jpg   2025-10-08
# 15  /tZRypLd2SU3Eeqg5tD5cwkk5CdL.jpg   2024-08-16
# 16  /p6xAExLNFbHcLfvSuvLPoM8aqZU.jpg   2025-11-30
# 17  /tc7RrVW5FGvyO2tsgW6LIN1esHI.jpg   2025-11-07
# 18  /qbImUt1d3itXcB81BCItPZlfbyr.jpg   2024-07-05
# 19  /cqF7xuZWbBYXWHsp1I1H5PwujPs.jpg   2025-03-17
#
#                                                 title  video  vote_average  \
# 0                                          Zootopia 2  False         7.639
# 1                                   The Shadow's Edge  False         6.332
# 2                                          Bureau 749  False         5.911
# 3                                             Altered  False         6.489
# 4                                             Wildcat  False         6.405
# 5                                         High Forces  False         6.100
# 6                                   The Family Plan 2  False         6.712
# 7                                             Dracula  False         7.000
# 8                                   She Rides Shotgun  False         7.082
# 9                                      Border Hunters  False         8.800
# 10                                   Wicked: For Good  False         6.800
# 11                                       Frankenstein  False         7.770
# 12                                 Predator: Badlands  False         7.373
# 13                                  War of the Worlds  False         4.301
# 14                                         TRON: Ares  False         6.295
# 15                                 Art of Eight Limbs  False         6.283
# 16                                            Troll 2  False         6.500
# 17  JUJUTSU KAISEN: Execution -Shibuya Incident x ...  False         4.800
# 18                                           A Legend  False         6.863
# 19                                        High Ground  False         6.044
#
#     vote_count
# 0          238
# 1          128
# 2           45
# 3           45
# 4           21
# 5           22
# 6          271
# 7          480
# 8          104
# 9            5
# 10         351
# 11        2013
# 12         514
# 13         760
# 14         427
# 15          30
# 16          22
# 17          40
# 18         118
# 19          34

# %% [markdown]
# ## Drop irrelevant columns

# %%
cols_to_drop = ['adult', 'imdb_id', 'original_title', 'video', 'homepage']
df = drop_irrelevant_columns(df, cols_to_drop)

# %%
df
# Out:
#                        backdrop_path                  genre_ids       id  \
# 0   /5h2EsPKNDdB3MAtOk9MB9Ycg9Rz.jpg  [16, 10751, 35, 12, 9648]  1084242
# 1   /4BtL2vvEufDXDP4u6xQjjQ1Y2aT.jpg               [28, 80, 53]  1419406
# 2   /lf8IZ86ajGpgbuyHCZrXUeAMmvy.jpg              [28, 12, 878]  1033462
# 3   /zEsHEpCGZwGg3M2b0oSZuaPLwBh.jpg                  [878, 28]  1309012
# 4   /pAyImoslSnpMgjRwhaS5ZEdl8UI.jpg               [28, 53, 80]  1448560
# 5   /8lqfrOBQ2EcY7znD3LxTYcvlh25.jpg                   [28, 80]   949709
# 6   /7nAVXGHHtaNcdsqvDXmY6R9N0fG.jpg                   [28, 35]  1363123
# 7   /nt0HRxlzOXRpPJtl2FmeBCO6MeR.jpg            [27, 14, 10749]  1246049
# 8   /ytCi1wg6YHpYcFRWCO2jpzN31Kf.jpg               [28, 53, 80]  1196573
# 9   /tRdorrIjlybrGsebXOzgF7vRyYy.jpg                   [28, 53]  1469354
# 10  /l8pwO23MCvqYumzozpxynCNfck1.jpg            [14, 12, 10749]   967941
# 11  /hpXBJxLD2SEf8l2CspmSeiHrBKX.jpg               [18, 14, 27]  1062722
# 12  /7hDFhV4ng4cHgSnxvO0MIb11Sbp.jpg              [28, 878, 12]  1242898
# 13  /iZLqwEwUViJdSkGVjePGhxYzbDb.jpg                  [878, 53]   755898
# 14  /g3lCbTn3HYHTiFrfusxKGXMdyUW.jpg              [878, 12, 28]   533533
# 15  /cVzAhirOhKh91AB1TFcGn0Rh5c3.jpg                   [28, 53]  1208561
# 16  /lZYMXx74pWmbj5Q5jp1QaMvmuuR.jpg               [28, 14, 53]  1180831
# 17  /eMBYlgFTHfZaTz96eJxlkeMsKo9.jpg                   [16, 28]  1539104
# 18  /7FDVhmCur4LMOfnXMteiSCtsdOb.jpg               [28, 12, 14]  1116465
# 19  /kyp7PSCKPZKGosthRbjfXPm8gJg.jpg               [53, 80, 28]  1433719
#
#    original_language                                           overview  \
# 0                 en  After cracking the biggest case in Zootopia's ...
# 1                 zh  Macau Police brings the tracking expert police...
# 2                 zh  A traumatized young man with physical abnormal...
# 3                 en  In an alternate present, genetically enhanced ...
# 4                 en  An ex-black ops team reunite to pull off a des...
# 5                 zh  "Anyone? There is ......" A mysterious message...
# 6                 en  Now that Dan's assassin days are behind him, a...
# 7                 fr  When a 15th-century prince denounces God after...
# 8                 en  Newly released from prison and marked for deat...
# 9                 en  After his police officer brother is killed by ...
# 10                en  As an angry mob rises against the Wicked Witch...
# 11                en  Dr. Victor Frankenstein, a brilliant but egoti...
# 12                en  Cast out from his clan, a young Predator finds...
# 13                en  Will Radford is a top analyst for Homeland Sec...
# 14                en  A highly sophisticated Program called Ares is ...
# 15                en  Four canisters of deadly VX nerve gas have fal...
# 16                no  When a dangerous new troll unleashes devastati...
# 17                ja  A veil abruptly descends over the busy Shibuya...
# 18                zh  An archeologist noticed that the texture of th...
# 19                en  When a mysterious prisoner lands in jail, a bo...
#
#     popularity                       poster_path release_date  \
# 0     588.0777  /oJ7g2CifqpStmoYQyaLQgEU32qO.jpg   2025-11-26
# 1     318.0550  /e0RU6KpdnrqFxDKlI3NOqN8nHL6.jpg   2025-08-16
# 2     279.8626  /flykCMw22y6yv8vKnBjmsW3pneo.jpg   2024-10-01
# 3     240.7323  /6QlAcGRaUrgHcZ4WTBh5lsPnzKx.jpg   2025-09-18
# 4     262.5736  /h893ImjM6Fsv5DFhKJdlZFZIJno.jpg   2025-11-19
# 5     255.7030  /v8ySgr4CE45SrrIt4PqqYc1diW6.jpg   2024-09-29
# 6     197.1049  /semFxuYx6HcrkZzslgAkBqfJvZk.jpg   2025-11-11
# 7     234.4226  /ykyRfv7JDofLxXLAwtLXaSuaFfM.jpg   2025-07-30
# 8     201.1906  /nvqW8mOm818QDio3GKKmPLK8kXj.jpg   2025-07-31
# 9     198.1722  /6TNFZnJ5CU0uFQxGaO9dbqriiI7.jpg   2025-10-20
# 10    196.1270  /si9tolnefLSUKaqQEGz1bWArOaL.jpg   2025-11-19
# 11    166.9899  /g4JtvGlQO7DByTI6frUobqvSL3R.jpg   2025-10-17
# 12    186.7735  /ef2QSeBkrYhAdfsWGXmp0lvH0T1.jpg   2025-11-05
# 13    154.2379  /yvirUYrva23IudARHn3mMGVxWqM.jpg   2025-07-29
# 14    172.1827  /chpWmskl3aKm1aTZqUHRCtviwPy.jpg   2025-10-08
# 15    172.8399  /tZRypLd2SU3Eeqg5tD5cwkk5CdL.jpg   2024-08-16
# 16    161.9837  /p6xAExLNFbHcLfvSuvLPoM8aqZU.jpg   2025-11-30
# 17    134.9268  /tc7RrVW5FGvyO2tsgW6LIN1esHI.jpg   2025-11-07
# 18    124.5523  /qbImUt1d3itXcB81BCItPZlfbyr.jpg   2024-07-05
# 19    103.5229  /cqF7xuZWbBYXWHsp1I1H5PwujPs.jpg   2025-03-17
#
#                                                 title  vote_average  \
# 0                                          Zootopia 2         7.639
# 1                                   The Shadow's Edge         6.332
# 2                                          Bureau 749         5.911
# 3                                             Altered         6.489
# 4                                             Wildcat         6.405
# 5                                         High Forces         6.100
# 6                                   The Family Plan 2         6.712
# 7                                             Dracula         7.000
# 8                                   She Rides Shotgun         7.082
# 9                                      Border Hunters         8.800
# 10                                   Wicked: For Good         6.800
# 11                                       Frankenstein         7.770
# 12                                 Predator: Badlands         7.373
# 13                                  War of the Worlds         4.301
# 14                                         TRON: Ares         6.295
# 15                                 Art of Eight Limbs         6.283
# 16                                            Troll 2         6.500
# 17  JUJUTSU KAISEN: Execution -Shibuya Incident x ...         4.800
# 18                                           A Legend         6.863
# 19                                        High Ground         6.044
#
#     vote_count
# 0          238
# 1          128
# 2           45
# 3           45
# 4           21
# 5           22
# 6          271
# 7          480
# 8          104
# 9            5
# 10         351
# 11        2013
# 12         514
# 13         760
# 14         427
# 15          30
# 16          22
# 17          40
# 18         118
# 19          34
