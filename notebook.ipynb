# %%
import sys
import importlib
import pandas as pd
sys.path.append("scripts")
importlib.reload(sys.modules['tmdb_client'])
importlib.reload(sys.modules['clean_data'])

from tmdb_client import fetch_popular_movies,get_movie_details, search_movie, get_all_movies_by_ids
from analysis import movies_to_dataframe, top_movies_by_popularity, plot_top_vote_average
from clean_data import drop_irrelevant_columns, clean_movie_data, inspect_categorical_columns_using_value_counts, replace_unrealistic_values, removing_na_and_duplicates

# %%
movies = fetch_popular_movies(page=1)

# %%
print(movies['results'])
# Out:
# [{'adult': False, 'backdrop_path': '/5h2EsPKNDdB3MAtOk9MB9Ycg9Rz.jpg', 'genre_ids': [16, 10751, 35, 12, 9648], 'id': 1084242, 'original_language': 'en', 'original_title': 'Zootopia 2', 'overview': "After cracking the biggest case in Zootopia's history, rookie cops Judy Hopps and Nick Wilde find themselves on the twisting trail of a great mystery when Gary De’Snake arrives and turns the animal metropolis upside down. To crack the case, Judy and Nick must go undercover to unexpected new parts of town, where their growing partnership is tested like never before.", 'popularity': 588.0777, 'poster_path': '/oJ7g2CifqpStmoYQyaLQgEU32qO.jpg', 'release_date': '2025-11-26', 'title': 'Zootopia 2', 'video': False, 'vote_average': 7.668, 'vote_count': 247}, {'adult': False, 'backdrop_path': '/4BtL2vvEufDXDP4u6xQjjQ1Y2aT.jpg', 'genre_ids': [28, 80, 53], 'id': 1419406, 'original_language': 'zh', 'original_title': '捕风追影', 'overview': 'Macau Police brings the tracking expert police officer out of retirement to help catch a dangerous group of professional thieves.', 'popularity': 318.055, 'poster_path': '/e0RU6KpdnrqFxDKlI3NOqN8nHL6.jpg', 'release_date': '2025-08-16', 'title': "The Shadow's Edge", 'video': False, 'vote_average': 6.3, 'vote_count': 128}, {'adult': False, 'backdrop_path': '/lf8IZ86ajGpgbuyHCZrXUeAMmvy.jpg', 'genre_ids': [28, 12, 878], 'id': 1033462, 'original_language': 'zh', 'original_title': '749局', 'overview': 'A traumatized young man with physical abnormalities is forced to join a mysterious bureau to confront a disaster spreading across the earth caused by an unknown creature. He embarks on an adventure uncovering mysteries about his life.', 'popularity': 279.8626, 'poster_path': '/flykCMw22y6yv8vKnBjmsW3pneo.jpg', 'release_date': '2024-10-01', 'title': 'Bureau 749', 'video': False, 'vote_average': 5.913, 'vote_count': 46}, {'adult': False, 'backdrop_path': '/zEsHEpCGZwGg3M2b0oSZuaPLwBh.jpg', 'genre_ids': [878, 28], 'id': 1309012, 'original_language': 'en', 'original_title': 'Altered', 'overview': 'In an alternate present, genetically enhanced humans dominate society. Outcasts Leon and Chloe fight for justice against corrupt politicians exploiting genetic disparity, risking everything to challenge the oppressive system.', 'popularity': 240.7323, 'poster_path': '/6QlAcGRaUrgHcZ4WTBh5lsPnzKx.jpg', 'release_date': '2025-09-18', 'title': 'Altered', 'video': False, 'vote_average': 6.489, 'vote_count': 45}, {'adult': False, 'backdrop_path': '/pAyImoslSnpMgjRwhaS5ZEdl8UI.jpg', 'genre_ids': [28, 53, 80], 'id': 1448560, 'original_language': 'en', 'original_title': 'Wildcar', 'overview': 'An ex-black ops team reunite to pull off a desperate heist in order to save the life of their leader’s eight-year-old daughter.', 'popularity': 262.5736, 'poster_path': '/h893ImjM6Fsv5DFhKJdlZFZIJno.jpg', 'release_date': '2025-11-19', 'title': 'Wildcar', 'video': False, 'vote_average': 6.409, 'vote_count': 22}, {'adult': False, 'backdrop_path': '/8lqfrOBQ2EcY7znD3LxTYcvlh25.jpg', 'genre_ids': [28, 80], 'id': 949709, 'original_language': 'zh', 'original_title': '危机航线', 'overview': '"Anyone? There is ......" A mysterious message from Gao Haojun comes from ten thousand meters in the air. A five-star A380 ultra-luxury airliner was hijacked on its international maiden voyage, and international security expert Gao Haojun stood up to a group of thugs, his daughter Xiaojun was trapped in the cabin, and Mike, the leader of the hijackers, threatened the lives of more than 800 people in the plane as a bargaining chip, and Xiaojun\'s mother, Fu Yuan, was also in danger. ...... Will the passengers on board be able to land safely and how should this crisis be resolved?', 'popularity': 255.703, 'poster_path': '/v8ySgr4CE45SrrIt4PqqYc1diW6.jpg', 'release_date': '2024-09-29', 'title': 'High Forces', 'video': False, 'vote_average': 6.1, 'vote_count': 22}, {'adult': False, 'backdrop_path': '/7nAVXGHHtaNcdsqvDXmY6R9N0fG.jpg', 'genre_ids': [28, 35], 'id': 1363123, 'origi ...

# %%
df_movies = movies_to_dataframe(movies['results'])

# %%
df_movies.head()
# Out:
#    adult                     backdrop_path                  genre_ids  \
# 0  False  /5h2EsPKNDdB3MAtOk9MB9Ycg9Rz.jpg  [16, 10751, 35, 12, 9648]
# 1  False  /4BtL2vvEufDXDP4u6xQjjQ1Y2aT.jpg               [28, 80, 53]
# 2  False  /lf8IZ86ajGpgbuyHCZrXUeAMmvy.jpg              [28, 12, 878]
# 3  False  /zEsHEpCGZwGg3M2b0oSZuaPLwBh.jpg                  [878, 28]
# 4  False  /pAyImoslSnpMgjRwhaS5ZEdl8UI.jpg               [28, 53, 80]
#
#         id original_language original_title  \
# 0  1084242                en     Zootopia 2
# 1  1419406                zh           捕风追影
# 2  1033462                zh           749局
# 3  1309012                en        Altered
# 4  1448560                en        Wildcar
#
#                                             overview  popularity  \
# 0  After cracking the biggest case in Zootopia's ...    588.0777
# 1  Macau Police brings the tracking expert police...    318.0550
# 2  A traumatized young man with physical abnormal...    279.8626
# 3  In an alternate present, genetically enhanced ...    240.7323
# 4  An ex-black ops team reunite to pull off a des...    262.5736
#
#                         poster_path release_date              title  video  \
# 0  /oJ7g2CifqpStmoYQyaLQgEU32qO.jpg   2025-11-26         Zootopia 2  False
# 1  /e0RU6KpdnrqFxDKlI3NOqN8nHL6.jpg   2025-08-16  The Shadow's Edge  False
# 2  /flykCMw22y6yv8vKnBjmsW3pneo.jpg   2024-10-01         Bureau 749  False
# 3  /6QlAcGRaUrgHcZ4WTBh5lsPnzKx.jpg   2025-09-18            Altered  False
# 4  /h893ImjM6Fsv5DFhKJdlZFZIJno.jpg   2025-11-19            Wildcar  False
#
#    vote_average  vote_count
# 0         7.668         247
# 1         6.300         128
# 2         5.913          46
# 3         6.489          45
# 4         6.409          22

# %%
zootopia_details = get_movie_details(1084242)
zootopia_details = pd.DataFrame([zootopia_details])

# %%
zootopia_details
# Out:
#    adult                     backdrop_path  \
# 0  False  /5h2EsPKNDdB3MAtOk9MB9Ycg9Rz.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 1084247, 'name': 'Zootopia Collection',...  150000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
#
#                                homepage       id     imdb_id origin_country  \
# 0  https://movies.disney.com/zootopia-2  1084242  tt26443597           [US]
#
#   original_language  ... release_date    revenue  runtime  \
# 0                en  ...   2025-11-26  560333554      107
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                  tagline       title  video  vote_average  \
# 0  Zootopia will be changed furrrever...  Zootopia 2  False           7.7
#
#   vote_count
# 0        246
#
# [1 rows x 26 columns]

# %% [markdown]
# ## Fetch all movies and store in a Database

# %%
movie_ids = [0, 299534, 19995, 140607, 299536, 597, 135397, 420818, 24428, 168259, 99861, 284054, 12445, 181808, 330457, 351286, 109445, 321612, 260513]

# %%
movies = get_all_movies_by_ids(movie_ids)

# %%
movies
# Out:
# [{'success': False,
#   'status_code': 6,
#   'status_message': 'Invalid id: The pre-requisite id is invalid or not found.'},
#  {'adult': False,
#   'backdrop_path': '/9wXPKruA6bWYk2co5ix6fH59Qr8.jpg',
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'budget': 356000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'}],
#   'homepage': 'https://www.marvel.com/movies/avengers-endgame',
#   'id': 299534,
#   'imdb_id': 'tt4154796',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Avengers: Endgame',
#   'overview': "After the devastating events of Avengers: Infinity War, the universe is in ruins due to the efforts of the Mad Titan, Thanos. With the help of remaining allies, the Avengers must assemble once more in order to undo Thanos' actions and restore order to the universe once and for all, no matter what consequences may be in store.",
#   'popularity': 13.7085,
#   'poster_path': '/bR8ISy1O9XQxqiy0fQFw2BX72RQ.jpg',
#   'production_companies': [{'id': 420,
#     'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#     'name': 'Marvel Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2019-04-24',
#   'revenue': 2799439100,
#   'runtime': 181,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Japanese', 'iso_639_1': 'ja', 'name': '日本語'},
#    {'english_name': 'Xhosa', 'iso_639_1': 'xh', 'name': ''}],
#   'status': 'Released',
#   'tagline': 'Avenge the fallen.',
#   'title': 'Avengers: Endgame',
#   'video': False,
#   'vote_average': 8.238,
#   'vote_count': 26959},
#  {'adult': False,
#   'backdrop_path': '/7JNzw1tSZZEgsBw6lu0VfO2X2Ef.jpg',
#   'belongs_to_collection': {'id': 87096,
#    'name': 'Avatar Collection',
#    'poster_path': '/3C5brXxnBxfkeKWwA1Fh4xvy4wr.jpg',
#    'backdrop_path': '/6qkJLRCZp9Y3ovXti5tSuhH0DpO.jpg'},
#   'budget': 237000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.avatar.com/movies/avatar',
#   'id': 19995,
#   'imdb_id': 'tt0499549',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Avatar',
#   'overview': 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.',
#   'popularity': 24.2976,
#   'poster_path': '/gKY6q7SjCkAU6FqvqWybDYgUKIF.jpg',
#   'production_companies': [{'id': 444,
#     'logo_path': None,
#     'name': 'Dune Entertainment',
#     'origin_country': 'US'},
#    {'id': 574,
#     'logo_path': '/8wdmrfGcDx3TJxYiiDksLzAW4pB.png',
#     'name': 'Lightstorm Entertainment',
#     'origin_country': 'US'},
#    {'id': 25,
#     'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png',
#     'name': '20th Century Fox',
#     'origin_country': 'US'},
#    {'id': 133789,
#     'logo_path': '/bJdeIb1ET3BkyodAASVDq1x3mls.png',
#     'name': 'Ingenious Film Partners',
#     'origin_country': 'GB'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'},
#    {'iso_3166_1': 'GB', 'name': 'United Kingdom'}],
#   'release_date': '2009-12-15',
#   'revenue': 2923706026,
#   'runtime': 162,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Spanish', 'iso_639_1': 'es', 'name': 'Español'}],
#   'status': 'Released',
#   'tagline': 'Enter the world of Pandora.',
#   'title': 'Avatar',
#   'video': False,
#   'vote_average': 7.594,
#   'vote_count': 32853},
#  {'adult': False,
#   'backdrop_path': '/8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg',
#   'belongs_to_collection': {'id': 10,
#    'name': 'Star Wars Collection',
#    'poster_path': '/22dj38IckjzEEUZwN1tPU5VJ1qq.jpg',
#    'backdrop_path': '/4z9ijhgEthfRHShoOvMaBlpciXS.jpg'},
#   'budget': 245000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'http://www.starwars.com/films/star-wars-episode-vii',
#   'id': 140607,
#   'imdb_id': 'tt2488496',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Star Wars: The Force Awakens',
#   'overview': 'Thirty years after defeating the Galactic Empire, Han Solo and his allies face a new threat from the evil Kylo Ren and his army of Stormtroopers.',
#   'popularity': 7.8068,
#   'poster_path': '/wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg',
#   'production_companies': [{'id': 1,
#     'logo_path': '/tlVSws0RvvtPBwViUyOFAO0vcQS.png',
#     'name': 'Lucasfilm Ltd.',
#     'origin_country': 'US'},
#    {'id': 11461,
#     'logo_path': '/p9FoEt5shEKRWRKVIlvFaEmRnun.png',
#     'name': 'Bad Robot',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2015-12-15',
#   'revenue': 2068223624,
#   'runtime': 136,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Every generation has a story.',
#   'title': 'Star Wars: The Force Awakens',
#   'video': False,
#   'vote_average': 7.3,
#   'vote_count': 20103},
#  {'adult': False,
#   'backdrop_path': '/mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg',
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'budget': 300000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.marvel.com/movies/avengers-infinity-war',
#   'id': 299536,
#   'imdb_id': 'tt4154756',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Avengers: Infinity War',
#   'overview': 'As the Avengers and their allies have continued to protect the world from threats too large for any one hero to handle, a new danger has emerged from the cosmic shadows: Thanos. A despot of intergalactic infamy, his goal is to collect all six Infinity Stones, artifacts of unimaginable power, and use them to inflict his twisted will on all of reality. Everything the Avengers have fought for has led up to this moment - the fate of Earth and existence itself has never been more uncertain.',
#   'popularity': 22.2327,
#   'poster_path': '/7WsyChQLEftFiDOVTGkv3hFpyyt.jpg',
#   'production_companies': [{'id': 420,
#     'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#     'name': 'Marvel Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2018-04-25',
#   'revenue': 2052415039,
#   'runtime': 149,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Xhosa', 'iso_639_1': 'xh', 'name': ''}],
#   'status': 'Released',
#   'tagline': 'Destiny arrives all the same.',
#   'title': 'Avengers: Infinity War',
#   'video': False,
#   'vote_average': 8.236,
#   'vote_count': 31176},
#  {'adult': False,
#   'backdrop_path': '/xnHVX37XZEp33hhCbYlQFq7ux1J.jpg',
#   'belongs_to_collection': None,
#   'budget': 200000000,
#   'genres': [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}],
#   'homepage': 'https://www.paramountmovies.com/movies/titanic',
#   'id': 597,
#   'imdb_id': 'tt0120338',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Titanic',
#   'overview': "101-year-old Rose DeWitt Bukater tells the story of her life aboard the Titanic, 84 years later. A young Rose boards the ship with her mother and fiancé. Meanwhile, Jack Dawson and Fabrizio De Rossi win third-class tickets aboard the ship. Rose tells the whole story from Titanic's departure through to its death—on its first and last voyage—on April 15, 1912.",
#   'popularity': 28.7753,
#   'poster_path': '/9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg',
#   'production_companies': [{'id': 4,
#     'logo_path': '/jay6WcMgagAklUt7i9Euwj1pzTF.png',
#     'name': 'Paramount Pictures',
#     'origin_country': 'US'},
#    {'id': 25,
#     'logo_path': '/qZCc1lty5FzX30aOCVRBLzaVmcp.png',
#     'name': '20th Century Fox',
#     'origin_country': 'US'},
#    {'id': 574,
#     'logo_path': '/8wdmrfGcDx3TJxYiiDksLzAW4pB.png',
#     'name': 'Lightstorm Entertainment',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '1997-11-18',
#   'revenue': 2264162353,
#   'runtime': 194,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'French', 'iso_639_1': 'fr', 'name': 'Français'},
#    {'english_name': 'German', 'iso_639_1': 'de', 'name': 'Deutsch'},
#    {'english_name': 'Swedish', 'iso_639_1': 'sv', 'name': 'svenska'},
#    {'english_name': 'Italian', 'iso_639_1': 'it', 'name': 'Italiano'},
#    {'english_name': 'Russian', 'iso_639_1': 'ru', 'name': 'Pусский'}],
#   'status': 'Released',
#   'tagline': 'Nothing on earth could come between them.',
#   'title': 'Titanic',
#   'video': False,
#   'vote_average': 7.903,
#   'vote_count': 26511},
#  {'adult': False,
#   'backdrop_path': '/dF6FjTZzRTENfB4R17HDN20jLT2.jpg',
#   'belongs_to_collection': {'id': 328,
#    'name': 'Jurassic Park Collection',
#    'poster_path': '/qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg',
#    'backdrop_path': '/njFixYzIxX8jsn6KMSEtAzi4avi.jpg'},
#   'budget': 150000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://www.jurassicworld.com/',
#   'id': 135397,
#   'imdb_id': 'tt0369610',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Jurassic World',
#   'overview': 'Twenty-two years after the events of Jurassic Park, Isla Nublar now features a fully functioning dinosaur theme park, Jurassic World, as originally envisioned by John Hammond.',
#   'popularity': 9.5096,
#   'poster_path': '/rhr4y79GpxQF9IsfJItRXVaoGs4.jpg',
#   'production_companies': [{'id': 56,
#     'logo_path': '/cEaxANEisCqeEoRvODv2dO1I0iI.png',
#     'name': 'Amblin Entertainment',
#     'origin_country': 'US'},
#    {'id': 33,
#     'logo_path': '/6exxhPonOo0M995SAchY0ijpRao.png',
#     'name': 'Universal Pictures',
#     'origin_country': 'US'},
#    {'id': 923,
#     'logo_path': '/5UQsZrfbfG2dYJbx8DxfoTr2Bvu.png',
#     'name': 'Legendary Pictures',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2015-06-06',
#   'revenue': 1671537444,
#   'runtime': 124,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'The park is open.',
#   'title': 'Jurassic World',
#   'video': False,
#   'vote_average': 6.7,
#   'vote_count': 21120},
#  {'adult': False,
#   'backdrop_path': '/1TUg5pO1VZ4B0Q1amk3OlXvlpXV.jpg',
#   'belongs_to_collection': {'id': 762512,
#    'name': 'The Lion King (Reboot) Collection',
#    'poster_path': '/dGpIRn4Nqi63JO1RlKxjcPbQSAw.jpg',
#    'backdrop_path': '/1KeXF239BkqLChcAcF8gKl1stZz.jpg'},
#   'budget': 260000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 18, 'name': 'Drama'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 16, 'name': 'Animation'}],
#   'homepage': 'https://movies.disney.com/the-lion-king-2019',
#   'id': 420818,
#   'imdb_id': 'tt6105098',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'The Lion King',
#   'overview': "Simba idolizes his father, King Mufasa, and takes to heart his own royal destiny. But not everyone in the kingdom celebrates the new cub's arrival. Scar, Mufasa's brother—and former heir to the throne—has plans of his own. The battle for Pride Rock is ravaged with betrayal, tragedy and drama, ultimately resulting in Simba's exile. With help from a curious pair of newfound friends, Simba will have to figure out how to grow up and take back what is rightfully his.",
#   'popularity': 9.0748,
#   'poster_path': '/dzBtMocZuJbjLOXvrl4zGYigDzh.jpg',
#   'production_companies': [{'id': 2,
#     'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png',
#     'name': 'Walt Disney Pictures',
#     'origin_country': 'US'},
#    {'id': 7297,
#     'logo_path': '/l29JYQVZbTcjZXoz4CUYFpKRmM3.png',
#     'name': 'Fairview Entertainment',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2019-07-12',
#   'revenue': 1662020819,
#   'runtime': 118,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'The king has returned.',
#   'title': 'The Lion King',
#   'video': False,
#   'vote_average': 7.103,
#   'vote_count': 10569},
#  {'adult': False,
#   'backdrop_path': '/9BBTo63ANSmhC4e6r62OJFuK2GL.jpg',
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'budget': 220000000,
#   'genres': [{'id': 878, 'name': 'Science Fiction'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'}],
#   'homepage': 'https://www.marvel.com/movies/the-avengers',
#   'id': 24428,
#   'imdb_id': 'tt0848228',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'The Avengers',
#   'overview': 'When an unexpected enemy emerges and threatens global safety and security, Nick Fury, director of the international peacekeeping agency known as S.H.I.E.L.D., finds himself in need of a team to pull the world back from the brink of disaster. Spanning the globe, a daring recruitment effort begins!',
#   'popularity': 45.5917,
#   'poster_path': '/RYMX2wcKCBAr24UyPD7xwmjaTn.jpg',
#   'production_companies': [{'id': 420,
#     'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#     'name': 'Marvel Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2012-04-25',
#   'revenue': 1518815515,
#   'runtime': 143,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Hindi', 'iso_639_1': 'hi', 'name': 'हिन्दी'},
#    {'english_name': 'Russian', 'iso_639_1': 'ru', 'name': 'Pусский'}],
#   'status': 'Released',
#   'tagline': 'Some assembly required.',
#   'title': 'The Avengers',
#   'video': False,
#   'vote_average': 7.865,
#   'vote_count': 34215},
#  {'adult': False,
#   'backdrop_path': '/ehzI1mVcnHqB58NqPyQwpMqcVoz.jpg',
#   'belongs_to_collection': {'id': 9485,
#    'name': 'The Fast and the Furious Collection',
#    'poster_path': '/zOCnMPoUxgJK1RFPfN4PcnT16gr.jpg',
#    'backdrop_path': '/z5A5W3WYJc3UVEWljSGwdjDgQ0j.jpg'},
#   'budget': 190000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 80, 'name': 'Crime'},
#    {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://www.uphe.com/movies/furious-7',
#   'id': 168259,
#   'imdb_id': 'tt2820852',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Furious 7',
#   'overview': 'Deckard Shaw seeks revenge against Dominic Toretto and his family for his comatose brother.',
#   'popularity': 8.675,
#   'poster_path': '/ktofZ9Htrjiy0P6LEowsDaxd3Ri.jpg',
#   'production_companies': [{'id': 333,
#     'logo_path': '/5xUJfzPZ8jWJUDzYtIeuPO4qPIa.png',
#     'name': 'Original Film',
#     'origin_country': 'US'},
#    {'id': 1225,
#     'logo_path': '/rIxhJMR7oK8b2fMakmTfRLY2TZv.png',
#     'name': 'One Race',
#     'origin_country': 'US'},
#    {'id': 33,
#     'logo_path': '/6exxhPonOo0M995SAchY0ijpRao.png',
#     'name': 'Universal Pictures',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2015-04-01',
#   'revenue': 1515400000,
#   'runtime': 139,
#   'spoken_languages': [{'english_name': 'Arabic',
#     'iso_639_1': 'ar',
#     'name': 'العربية'},
#    {'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'},
#    {'english_name': 'Spanish', 'iso_639_1': 'es', 'name': 'Español'},
#    {'english_name': 'Thai', 'iso_639_1': 'th', 'name': 'ภาษาไทย'}],
#   'status': 'Released',
#   'tagline': 'Vengeance hits home.',
#   'title': 'Furious 7',
#   'video': False,
#   'vote_average': 7.223,
#   'vote_count': 11030},
#  {'adult': False,
#   'backdrop_path': '/kIBK5SKwgqIIuRKhhWrJn3XkbPq.jpg',
#   'belongs_to_collection': {'id': 86311,
#    'name': 'The Avengers Collection',
#    'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg',
#    'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'},
#   'budget': 235000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.marvel.com/movies/avengers-age-of-ultron',
#   'id': 99861,
#   'imdb_id': 'tt2395427',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Avengers: Age of Ultron',
#   'overview': 'When Tony Stark tries to jumpstart a dormant peacekeeping program, things go awry and Earth’s Mightiest Heroes are put to the ultimate test as the fate of the planet hangs in the balance. As the villainous Ultron emerges, it is up to The Avengers to stop him from enacting his terrible plans, and soon uneasy alliances and unexpected action pave the way for an epic and unique global adventure.',
#   'popularity': 10.5454,
#   'poster_path': '/4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg',
#   'production_companies': [{'id': 420,
#     'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#     'name': 'Marvel Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2015-04-22',
#   'revenue': 1405403694,
#   'runtime': 141,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'A new age has come.',
#   'title': 'Avengers: Age of Ultron',
#   'video': False,
#   'vote_average': 7.3,
#   'vote_count': 23875},
#  {'adult': False,
#   'backdrop_path': '/b6ZJZHUdMEFECvGiDpJjlfUWela.jpg',
#   'belongs_to_collection': {'id': 529892,
#    'name': 'Black Panther Collection',
#    'poster_path': '/VtMkk2s92SnDUt8eYyUyYaSJQK.jpg',
#    'backdrop_path': '/nsiBzWsmmerBMuD8TKHpYBTnfhD.jpg'},
#   'budget': 200000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.marvel.com/movies/black-panther',
#   'id': 284054,
#   'imdb_id': 'tt1825683',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Black Panther',
#   'overview': "King T'Challa returns home to the reclusive, technologically advanced African nation of Wakanda to serve as his country's new leader. However, T'Challa soon finds that he is challenged for the throne by factions within his own country as well as without. Using powers reserved to Wakandan kings, T'Challa assumes the Black Panther mantle to join with ex-girlfriend Nakia, the queen-mother, his princess-kid sister, members of the Dora Milaje (the Wakandan 'special forces') and an American secret agent, to prevent Wakanda from being dragged into a world war.",
#   'popularity': 8.6974,
#   'poster_path': '/uxzzxijgPIY7slzFvMotPv8wjKA.jpg',
#   'production_companies': [{'id': 420,
#     'logo_path': '/hUzeosd33nzE5MCNsZxCGEKTXaQ.png',
#     'name': 'Marvel Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2018-02-13',
#   'revenue': 1349926083,
#   'runtime': 135,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Korean', 'iso_639_1': 'ko', 'name': '한국어/조선말'},
#    {'english_name': 'Swahili', 'iso_639_1': 'sw', 'name': 'Kiswahili'},
#    {'english_name': 'Xhosa', 'iso_639_1': 'xh', 'name': ''}],
#   'status': 'Released',
#   'tagline': 'Long live the king.',
#   'title': 'Black Panther',
#   'video': False,
#   'vote_average': 7.366,
#   'vote_count': 22970},
#  {'adult': False,
#   'backdrop_path': '/n5A7brJCjejceZmHyujwUTVgQNC.jpg',
#   'belongs_to_collection': {'id': 1241,
#    'name': 'Harry Potter Collection',
#    'poster_path': '/eVPs2Y0LyvTLZn6AP5Z6O2rtiGB.jpg',
#    'backdrop_path': '/kmEsQL2vOTA0jnM28fXS45Ky8kX.jpg'},
#   'budget': 125000000,
#   'genres': [{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}],
#   'homepage': 'https://www.warnerbros.com/movies/harry-potter-and-deathly-hallows-part-2',
#   'id': 12445,
#   'imdb_id': 'tt1201607',
#   'origin_country': ['GB'],
#   'original_language': 'en',
#   'original_title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'overview': "Harry, Ron and Hermione continue their quest to vanquish the evil Voldemort once and for all. Just as things begin to look hopeless for the young wizards, Harry discovers a trio of magical objects that endow him with powers to rival Voldemort's formidable skills.",
#   'popularity': 16.6485,
#   'poster_path': '/c54HpQmuwXjHq2C9wmoACjxoom3.jpg',
#   'production_companies': [{'id': 174,
#     'logo_path': '/ingPVoHnINIrFR7WHmYux1f5pES.png',
#     'name': 'Warner Bros. Pictures',
#     'origin_country': 'US'},
#    {'id': 437,
#     'logo_path': '/nu20mtwbEIhUNnQ5NXVhHsNknZj.png',
#     'name': 'Heyday Films',
#     'origin_country': 'GB'}],
#   'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#    {'iso_3166_1': 'US', 'name': 'United States of America'}],
#   'release_date': '2011-07-12',
#   'revenue': 1341511219,
#   'runtime': 130,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'It all ends.',
#   'title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'video': False,
#   'vote_average': 8.084,
#   'vote_count': 21450},
#  {'adult': False,
#   'backdrop_path': '/5Iw7zQTHVRBOYpA0V6z0yypOPZh.jpg',
#   'belongs_to_collection': {'id': 10,
#    'name': 'Star Wars Collection',
#    'poster_path': '/22dj38IckjzEEUZwN1tPU5VJ1qq.jpg',
#    'backdrop_path': '/4z9ijhgEthfRHShoOvMaBlpciXS.jpg'},
#   'budget': 300000000,
#   'genres': [{'id': 12, 'name': 'Adventure'},
#    {'id': 28, 'name': 'Action'},
#    {'id': 878, 'name': 'Science Fiction'}],
#   'homepage': 'https://www.starwars.com/films/star-wars-episode-viii-the-last-jedi',
#   'id': 181808,
#   'imdb_id': 'tt2527336',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Star Wars: The Last Jedi',
#   'overview': 'Rey develops her newly discovered abilities with the guidance of Luke Skywalker, who is unsettled by the strength of her powers. Meanwhile, the Resistance prepares to do battle with the First Order.',
#   'popularity': 6.9144,
#   'poster_path': '/kOVEVeg59E0wsnXmF9nrh6OmWII.jpg',
#   'production_companies': [{'id': 1,
#     'logo_path': '/tlVSws0RvvtPBwViUyOFAO0vcQS.png',
#     'name': 'Lucasfilm Ltd.',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2017-12-13',
#   'revenue': 1332698830,
#   'runtime': 152,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Let the Past Die',
#   'title': 'Star Wars: The Last Jedi',
#   'video': False,
#   'vote_average': 6.8,
#   'vote_count': 15926},
#  {'adult': False,
#   'backdrop_path': '/AoSZyb37ljMAxw0RdeQEBHKtgcc.jpg',
#   'belongs_to_collection': {'id': 386382,
#    'name': 'Frozen Collection',
#    'poster_path': '/13Op41T3cALJedrKqYPrlc3cIbO.jpg',
#    'backdrop_path': '/s3vdRkK7KZFUDC8HEJo2GRKyVhW.jpg'},
#   'budget': 150000000,
#   'genres': [{'id': 10751, 'name': 'Family'},
#    {'id': 16, 'name': 'Animation'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 35, 'name': 'Comedy'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'homepage': 'https://movies.disney.com/frozen-2',
#   'id': 330457,
#   'imdb_id': 'tt4520988',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Frozen II',
#   'overview': 'Elsa, Anna, Kristoff and Olaf head far into the forest to learn the truth about an ancient mystery of their kingdom.',
#   'popularity': 10.0343,
#   'poster_path': '/mINJaa34MtknCYl5AjtNJzWj8cD.jpg',
#   'production_companies': [{'id': 6125,
#     'logo_path': '/tzsMJBJZINu7GHzrpYzpReWhh66.png',
#     'name': 'Walt Disney Animation Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2019-11-20',
#   'revenue': 1453683476,
#   'runtime': 103,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'The past is not what it seems.',
#   'title': 'Frozen II',
#   'video': False,
#   'vote_average': 7.241,
#   'vote_count': 10071},
#  {'adult': False,
#   'backdrop_path': '/gBmrsugfWpiXRh13Vo3j0WW55qD.jpg',
#   'belongs_to_collection': {'id': 328,
#    'name': 'Jurassic Park Collection',
#    'poster_path': '/qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg',
#    'backdrop_path': '/njFixYzIxX8jsn6KMSEtAzi4avi.jpg'},
#   'budget': 170000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 878, 'name': 'Science Fiction'},
#    {'id': 53, 'name': 'Thriller'}],
#   'homepage': 'https://www.uphe.com/movies/jurassic-world-fallen-kingdom',
#   'id': 351286,
#   'imdb_id': 'tt4881806',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Jurassic World: Fallen Kingdom',
#   'overview': "Three years after Jurassic World was destroyed, Isla Nublar now sits abandoned. When the island's dormant volcano begins roaring to life, Owen and Claire mount a campaign to rescue the remaining dinosaurs from this extinction-level event.",
#   'popularity': 9.2901,
#   'poster_path': '/x8cLgs0uXlb9rmpuVIxopoRGnCr.jpg',
#   'production_companies': [{'id': 56,
#     'logo_path': '/cEaxANEisCqeEoRvODv2dO1I0iI.png',
#     'name': 'Amblin Entertainment',
#     'origin_country': 'US'},
#    {'id': 33,
#     'logo_path': '/6exxhPonOo0M995SAchY0ijpRao.png',
#     'name': 'Universal Pictures',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2018-06-06',
#   'revenue': 1310469037,
#   'runtime': 129,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'Russian', 'iso_639_1': 'ru', 'name': 'Pусский'}],
#   'status': 'Released',
#   'tagline': 'The park is gone.',
#   'title': 'Jurassic World: Fallen Kingdom',
#   'video': False,
#   'vote_average': 6.538,
#   'vote_count': 12408},
#  {'adult': False,
#   'backdrop_path': '/u2bZhH3nTf0So0UIC1QxAqBvC07.jpg',
#   'belongs_to_collection': {'id': 386382,
#    'name': 'Frozen Collection',
#    'poster_path': '/13Op41T3cALJedrKqYPrlc3cIbO.jpg',
#    'backdrop_path': '/s3vdRkK7KZFUDC8HEJo2GRKyVhW.jpg'},
#   'budget': 150000000,
#   'genres': [{'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 14, 'name': 'Fantasy'}],
#   'homepage': 'http://movies.disney.com/frozen',
#   'id': 109445,
#   'imdb_id': 'tt2294629',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Frozen',
#   'overview': "Young princess Anna of Arendelle dreams about finding true love at her sister Elsa’s coronation. Fate takes her on a dangerous journey in an attempt to end the eternal winter that has fallen over the kingdom. She's accompanied by ice delivery man Kristoff, his reindeer Sven, and snowman Olaf. On an adventure where she will find out what friendship, courage, family, and true love really means.",
#   'popularity': 20.426,
#   'poster_path': '/itAKcobTYGpYT8Phwjd8c9hleTo.jpg',
#   'production_companies': [{'id': 6125,
#     'logo_path': '/tzsMJBJZINu7GHzrpYzpReWhh66.png',
#     'name': 'Walt Disney Animation Studios',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2013-11-20',
#   'revenue': 1274219009,
#   'runtime': 102,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': 'Who will save the day? The ice guy? The nice guy? The snow man? Or no man?',
#   'title': 'Frozen',
#   'video': False,
#   'vote_average': 7.249,
#   'vote_count': 17182},
#  {'adult': False,
#   'backdrop_path': '/uU1Mt4JWhDvl4vKb3AfxNsorkoM.jpg',
#   'belongs_to_collection': None,
#   'budget': 160000000,
#   'genres': [{'id': 10751, 'name': 'Family'},
#    {'id': 14, 'name': 'Fantasy'},
#    {'id': 10749, 'name': 'Romance'}],
#   'homepage': 'http://movies.disney.com/beauty-and-the-beast-2017',
#   'id': 321612,
#   'imdb_id': 'tt2771200',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Beauty and the Beast',
#   'overview': "A live-action adaptation of Disney's version of the classic tale of a cursed prince and a beautiful young woman who helps him break the spell.",
#   'popularity': 11.9931,
#   'poster_path': '/hKegSKIDep2ewJWPUQD7u0KqFIp.jpg',
#   'production_companies': [{'id': 2,
#     'logo_path': '/wdrCwmRnLFJhEoH8GSfymY85KHT.png',
#     'name': 'Walt Disney Pictures',
#     'origin_country': 'US'},
#    {'id': 10227,
#     'logo_path': '/3YfRy3DBl4abcqkzGx4RVNz12yl.png',
#     'name': 'Mandeville Films',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2017-03-16',
#   'revenue': 1266115964,
#   'runtime': 129,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'},
#    {'english_name': 'French', 'iso_639_1': 'fr', 'name': 'Français'}],
#   'status': 'Released',
#   'tagline': 'Be our guest.',
#   'title': 'Beauty and the Beast',
#   'video': False,
#   'vote_average': 6.969,
#   'vote_count': 15831},
#  {'adult': False,
#   'backdrop_path': '/mabuNsGJgRuCTuGqjFkWe1xdu19.jpg',
#   'belongs_to_collection': {'id': 468222,
#    'name': 'The Incredibles Collection',
#    'poster_path': '/iOz4Zz72JIqkuTXSnbvNoloA6oD.jpg',
#    'backdrop_path': '/6oi6V1O9MJRNnfV8E9JMntmFqBD.jpg'},
#   'budget': 200000000,
#   'genres': [{'id': 28, 'name': 'Action'},
#    {'id': 12, 'name': 'Adventure'},
#    {'id': 16, 'name': 'Animation'},
#    {'id': 10751, 'name': 'Family'}],
#   'homepage': 'https://movies.disney.com/incredibles-2',
#   'id': 260513,
#   'imdb_id': 'tt3606756',
#   'origin_country': ['US'],
#   'original_language': 'en',
#   'original_title': 'Incredibles 2',
#   'overview': 'Elastigirl springs into action to save the day, while Mr. Incredible faces his greatest challenge yet – taking care of the problems of his three children.',
#   'popularity': 10.7522,
#   'poster_path': '/9lFKBtaVIhP7E2Pk0IY1CwTKTMZ.jpg',
#   'production_companies': [{'id': 3,
#     'logo_path': '/1TjvGVDMYsj6JBxOAkUHpPEwLf7.png',
#     'name': 'Pixar',
#     'origin_country': 'US'}],
#   'production_countries': [{'iso_3166_1': 'US',
#     'name': 'United States of America'}],
#   'release_date': '2018-06-14',
#   'revenue': 1243225667,
#   'runtime': 118,
#   'spoken_languages': [{'english_name': 'English',
#     'iso_639_1': 'en',
#     'name': 'English'}],
#   'status': 'Released',
#   'tagline': "It's been too long, dahlings.",
#   'title': 'Incredibles 2',
#   'video': False,
#   'vote_average': 7.456,
#   'vote_count': 13366}]

# %%
df = movies_to_dataframe(movies)

# %%
df
# Out:
#    success  status_code                                     status_message  \
# 0    False          6.0  Invalid id: The pre-requisite id is invalid or...
# 1      NaN          NaN                                                NaN
# 2      NaN          NaN                                                NaN
# 3      NaN          NaN                                                NaN
# 4      NaN          NaN                                                NaN
# 5      NaN          NaN                                                NaN
# 6      NaN          NaN                                                NaN
# 7      NaN          NaN                                                NaN
# 8      NaN          NaN                                                NaN
# 9      NaN          NaN                                                NaN
# 10     NaN          NaN                                                NaN
# 11     NaN          NaN                                                NaN
# 12     NaN          NaN                                                NaN
# 13     NaN          NaN                                                NaN
# 14     NaN          NaN                                                NaN
# 15     NaN          NaN                                                NaN
# 16     NaN          NaN                                                NaN
# 17     NaN          NaN                                                NaN
# 18     NaN          NaN                                                NaN
#
#     adult                     backdrop_path  \
# 0     NaN                               NaN
# 1   False  /9wXPKruA6bWYk2co5ix6fH59Qr8.jpg
# 2   False  /7JNzw1tSZZEgsBw6lu0VfO2X2Ef.jpg
# 3   False  /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg
# 4   False  /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg
# 5   False  /xnHVX37XZEp33hhCbYlQFq7ux1J.jpg
# 6   False  /dF6FjTZzRTENfB4R17HDN20jLT2.jpg
# 7   False  /1TUg5pO1VZ4B0Q1amk3OlXvlpXV.jpg
# 8   False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 9   False  /ehzI1mVcnHqB58NqPyQwpMqcVoz.jpg
# 10  False  /kIBK5SKwgqIIuRKhhWrJn3XkbPq.jpg
# 11  False  /b6ZJZHUdMEFECvGiDpJjlfUWela.jpg
# 12  False  /n5A7brJCjejceZmHyujwUTVgQNC.jpg
# 13  False  /5Iw7zQTHVRBOYpA0V6z0yypOPZh.jpg
# 14  False  /AoSZyb37ljMAxw0RdeQEBHKtgcc.jpg
# 15  False  /gBmrsugfWpiXRh13Vo3j0WW55qD.jpg
# 16  False  /u2bZhH3nTf0So0UIC1QxAqBvC07.jpg
# 17  False  /uU1Mt4JWhDvl4vKb3AfxNsorkoM.jpg
# 18  False  /mabuNsGJgRuCTuGqjFkWe1xdu19.jpg
#
#                                 belongs_to_collection       budget  \
# 0                                                 NaN          NaN
# 1   {'id': 86311, 'name': 'The Avengers Collection...  356000000.0
# 2   {'id': 87096, 'name': 'Avatar Collection', 'po...  237000000.0
# 3   {'id': 10, 'name': 'Star Wars Collection', 'po...  245000000.0
# 4   {'id': 86311, 'name': 'The Avengers Collection...  300000000.0
# 5                                                None  200000000.0
# 6   {'id': 328, 'name': 'Jurassic Park Collection'...  150000000.0
# 7   {'id': 762512, 'name': 'The Lion King (Reboot)...  260000000.0
# 8   {'id': 86311, 'name': 'The Avengers Collection...  220000000.0
# 9   {'id': 9485, 'name': 'The Fast and the Furious...  190000000.0
# 10  {'id': 86311, 'name': 'The Avengers Collection...  235000000.0
# 11  {'id': 529892, 'name': 'Black Panther Collecti...  200000000.0
# 12  {'id': 1241, 'name': 'Harry Potter Collection'...  125000000.0
# 13  {'id': 10, 'name': 'Star Wars Collection', 'po...  300000000.0
# 14  {'id': 386382, 'name': 'Frozen Collection', 'p...  150000000.0
# 15  {'id': 328, 'name': 'Jurassic Park Collection'...  170000000.0
# 16  {'id': 386382, 'name': 'Frozen Collection', 'p...  150000000.0
# 17                                               None  160000000.0
# 18  {'id': 468222, 'name': 'The Incredibles Collec...  200000000.0
#
#                                                genres  \
# 0                                                 NaN
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 2   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 5   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 6   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 7   [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# 8   [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 9   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 11  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 12  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 13  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 14  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 15  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 16  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 17  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# 18  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                              homepage        id  ...  \
# 0                                                 NaN       NaN  ...
# 1      https://www.marvel.com/movies/avengers-endgame  299534.0  ...
# 2                https://www.avatar.com/movies/avatar   19995.0  ...
# 3   http://www.starwars.com/films/star-wars-episod...  140607.0  ...
# 4   https://www.marvel.com/movies/avengers-infinit...  299536.0  ...
# 5      https://www.paramountmovies.com/movies/titanic     597.0  ...
# 6                      https://www.jurassicworld.com/  135397.0  ...
# 7        https://movies.disney.com/the-lion-king-2019  420818.0  ...
# 8          https://www.marvel.com/movies/the-avengers   24428.0  ...
# 9               https://www.uphe.com/movies/furious-7  168259.0  ...
# 10  https://www.marvel.com/movies/avengers-age-of-...   99861.0  ...
# 11        https://www.marvel.com/movies/black-panther  284054.0  ...
# 12  https://www.warnerbros.com/movies/harry-potter...   12445.0  ...
# 13  https://www.starwars.com/films/star-wars-episo...  181808.0  ...
# 14                 https://movies.disney.com/frozen-2  330457.0  ...
# 15  https://www.uphe.com/movies/jurassic-world-fal...  351286.0  ...
# 16                    http://movies.disney.com/frozen  109445.0  ...
# 17  http://movies.disney.com/beauty-and-the-beast-...  321612.0  ...
# 18            https://movies.disney.com/incredibles-2  260513.0  ...
#
#    release_date       revenue runtime  \
# 0           NaN           NaN     NaN
# 1    2019-04-24  2.799439e+09   181.0
# 2    2009-12-15  2.923706e+09   162.0
# 3    2015-12-15  2.068224e+09   136.0
# 4    2018-04-25  2.052415e+09   149.0
# 5    1997-11-18  2.264162e+09   194.0
# 6    2015-06-06  1.671537e+09   124.0
# 7    2019-07-12  1.662021e+09   118.0
# 8    2012-04-25  1.518816e+09   143.0
# 9    2015-04-01  1.515400e+09   139.0
# 10   2015-04-22  1.405404e+09   141.0
# 11   2018-02-13  1.349926e+09   135.0
# 12   2011-07-12  1.341511e+09   130.0
# 13   2017-12-13  1.332699e+09   152.0
# 14   2019-11-20  1.453683e+09   103.0
# 15   2018-06-06  1.310469e+09   129.0
# 16   2013-11-20  1.274219e+09   102.0
# 17   2017-03-16  1.266116e+09   129.0
# 18   2018-06-14  1.243226e+09   118.0
#
#                                      spoken_languages    status  \
# 0                                                 NaN       NaN
# 1   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 5   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 6   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 7   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 8   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 9   [{'english_name': 'Arabic', 'iso_639_1': 'ar',...  Released
# 10  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 11  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 12  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 13  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 14  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 15  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 16  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 17  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 18  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                               tagline  \
# 0                                                 NaN
# 1                                  Avenge the fallen.
# 2                         Enter the world of Pandora.
# 3                       Every generation has a story.
# 4                       Destiny arrives all the same.
# 5           Nothing on earth could come between them.
# 6                                   The park is open.
# 7                              The king has returned.
# 8                             Some assembly required.
# 9                                Vengeance hits home.
# 10                                A new age has come.
# 11                                Long live the king.
# 12                                       It all ends.
# 13                                   Let the Past Die
# 14                     The past is not what it seems.
# 15                                  The park is gone.
# 16  Who will save the day? The ice guy? The nice g...
# 17                                      Be our guest.
# 18                      It's been too long, dahlings.
#
#                                            title  video vote_average  \
# 0                                            NaN    NaN          NaN
# 1                              Avengers: Endgame  False        8.238
# 2                                         Avatar  False        7.594
# 3                   Star Wars: The Force Awakens  False        7.300
# 4                         Avengers: Infinity War  False        8.236
# 5                                        Titanic  False        7.903
# 6                                 Jurassic World  False        6.700
# 7                                  The Lion King  False        7.103
# 8                                   The Avengers  False        7.865
# 9                                      Furious 7  False        7.223
# 10                       Avengers: Age of Ultron  False        7.300
# 11                                 Black Panther  False        7.366
# 12  Harry Potter and the Deathly Hallows: Part 2  False        8.084
# 13                      Star Wars: The Last Jedi  False        6.800
# 14                                     Frozen II  False        7.241
# 15                Jurassic World: Fallen Kingdom  False        6.538
# 16                                        Frozen  False        7.249
# 17                          Beauty and the Beast  False        6.969
# 18                                 Incredibles 2  False        7.456
#
#    vote_count
# 0         NaN
# 1     26959.0
# 2     32853.0
# 3     20103.0
# 4     31176.0
# 5     26511.0
# 6     21120.0
# 7     10569.0
# 8     34215.0
# 9     11030.0
# 10    23875.0
# 11    22970.0
# 12    21450.0
# 13    15926.0
# 14    10071.0
# 15    12408.0
# 16    17182.0
# 17    15831.0
# 18    13366.0
#
# [19 rows x 29 columns]

# %% [markdown]
# ## Drop irrelevant columns

# %%
cols_to_drop = ['adult', 'imdb_id', 'original_title', 'video', 'homepage', 	'success', 'status_code', 'status_message']
df = drop_irrelevant_columns(df, cols_to_drop)

# %%
df
# Out:
#                        backdrop_path  \
# 0                                NaN
# 1   /9wXPKruA6bWYk2co5ix6fH59Qr8.jpg
# 2   /7JNzw1tSZZEgsBw6lu0VfO2X2Ef.jpg
# 3   /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg
# 4   /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg
# 5   /xnHVX37XZEp33hhCbYlQFq7ux1J.jpg
# 6   /dF6FjTZzRTENfB4R17HDN20jLT2.jpg
# 7   /1TUg5pO1VZ4B0Q1amk3OlXvlpXV.jpg
# 8   /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg
# 9   /ehzI1mVcnHqB58NqPyQwpMqcVoz.jpg
# 10  /kIBK5SKwgqIIuRKhhWrJn3XkbPq.jpg
# 11  /b6ZJZHUdMEFECvGiDpJjlfUWela.jpg
# 12  /n5A7brJCjejceZmHyujwUTVgQNC.jpg
# 13  /5Iw7zQTHVRBOYpA0V6z0yypOPZh.jpg
# 14  /AoSZyb37ljMAxw0RdeQEBHKtgcc.jpg
# 15  /gBmrsugfWpiXRh13Vo3j0WW55qD.jpg
# 16  /u2bZhH3nTf0So0UIC1QxAqBvC07.jpg
# 17  /uU1Mt4JWhDvl4vKb3AfxNsorkoM.jpg
# 18  /mabuNsGJgRuCTuGqjFkWe1xdu19.jpg
#
#                                 belongs_to_collection       budget  \
# 0                                                 NaN          NaN
# 1   {'id': 86311, 'name': 'The Avengers Collection...  356000000.0
# 2   {'id': 87096, 'name': 'Avatar Collection', 'po...  237000000.0
# 3   {'id': 10, 'name': 'Star Wars Collection', 'po...  245000000.0
# 4   {'id': 86311, 'name': 'The Avengers Collection...  300000000.0
# 5                                                None  200000000.0
# 6   {'id': 328, 'name': 'Jurassic Park Collection'...  150000000.0
# 7   {'id': 762512, 'name': 'The Lion King (Reboot)...  260000000.0
# 8   {'id': 86311, 'name': 'The Avengers Collection...  220000000.0
# 9   {'id': 9485, 'name': 'The Fast and the Furious...  190000000.0
# 10  {'id': 86311, 'name': 'The Avengers Collection...  235000000.0
# 11  {'id': 529892, 'name': 'Black Panther Collecti...  200000000.0
# 12  {'id': 1241, 'name': 'Harry Potter Collection'...  125000000.0
# 13  {'id': 10, 'name': 'Star Wars Collection', 'po...  300000000.0
# 14  {'id': 386382, 'name': 'Frozen Collection', 'p...  150000000.0
# 15  {'id': 328, 'name': 'Jurassic Park Collection'...  170000000.0
# 16  {'id': 386382, 'name': 'Frozen Collection', 'p...  150000000.0
# 17                                               None  160000000.0
# 18  {'id': 468222, 'name': 'The Incredibles Collec...  200000000.0
#
#                                                genres        id  \
# 0                                                 NaN       NaN
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...  299534.0
# 2   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...   19995.0
# 3   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...  140607.0
# 4   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...  299536.0
# 5   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...     597.0
# 6   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  135397.0
# 7   [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...  420818.0
# 8   [{'id': 878, 'name': 'Science Fiction'}, {'id'...   24428.0
# 9   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...  168259.0
# 10  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...   99861.0
# 11  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  284054.0
# 12  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   12445.0
# 13  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...  181808.0
# 14  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...  330457.0
# 15  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  351286.0
# 16  [{'id': 16, 'name': 'Animation'}, {'id': 10751...  109445.0
# 17  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...  321612.0
# 18  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...  260513.0
#
#    origin_country original_language  \
# 0             NaN               NaN
# 1            [US]                en
# 2            [US]                en
# 3            [US]                en
# 4            [US]                en
# 5            [US]                en
# 6            [US]                en
# 7            [US]                en
# 8            [US]                en
# 9            [US]                en
# 10           [US]                en
# 11           [US]                en
# 12           [GB]                en
# 13           [US]                en
# 14           [US]                en
# 15           [US]                en
# 16           [US]                en
# 17           [US]                en
# 18           [US]                en
#
#                                              overview  popularity  \
# 0                                                 NaN         NaN
# 1   After the devastating events of Avengers: Infi...     13.7085
# 2   In the 22nd century, a paraplegic Marine is di...     24.2976
# 3   Thirty years after defeating the Galactic Empi...      7.8068
# 4   As the Avengers and their allies have continue...     22.2327
# 5   101-year-old Rose DeWitt Bukater tells the sto...     28.7753
# 6   Twenty-two years after the events of Jurassic ...      9.5096
# 7   Simba idolizes his father, King Mufasa, and ta...      9.0748
# 8   When an unexpected enemy emerges and threatens...     45.5917
# 9   Deckard Shaw seeks revenge against Dominic Tor...      8.6750
# 10  When Tony Stark tries to jumpstart a dormant p...     10.5454
# 11  King T'Challa returns home to the reclusive, t...      8.6974
# 12  Harry, Ron and Hermione continue their quest t...     16.6485
# 13  Rey develops her newly discovered abilities wi...      6.9144
# 14  Elsa, Anna, Kristoff and Olaf head far into th...     10.0343
# 15  Three years after Jurassic World was destroyed...      9.2901
# 16  Young princess Anna of Arendelle dreams about ...     20.4260
# 17  A live-action adaptation of Disney's version o...     11.9931
# 18  Elastigirl springs into action to save the day...     10.7522
#
#                          poster_path  ...  \
# 0                                NaN  ...
# 1   /bR8ISy1O9XQxqiy0fQFw2BX72RQ.jpg  ...
# 2   /gKY6q7SjCkAU6FqvqWybDYgUKIF.jpg  ...
# 3   /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg  ...
# 4   /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg  ...
# 5   /9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg  ...
# 6   /rhr4y79GpxQF9IsfJItRXVaoGs4.jpg  ...
# 7   /dzBtMocZuJbjLOXvrl4zGYigDzh.jpg  ...
# 8    /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg  ...
# 9   /ktofZ9Htrjiy0P6LEowsDaxd3Ri.jpg  ...
# 10  /4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg  ...
# 11  /uxzzxijgPIY7slzFvMotPv8wjKA.jpg  ...
# 12  /c54HpQmuwXjHq2C9wmoACjxoom3.jpg  ...
# 13  /kOVEVeg59E0wsnXmF9nrh6OmWII.jpg  ...
# 14  /mINJaa34MtknCYl5AjtNJzWj8cD.jpg  ...
# 15  /x8cLgs0uXlb9rmpuVIxopoRGnCr.jpg  ...
# 16  /itAKcobTYGpYT8Phwjd8c9hleTo.jpg  ...
# 17  /hKegSKIDep2ewJWPUQD7u0KqFIp.jpg  ...
# 18  /9lFKBtaVIhP7E2Pk0IY1CwTKTMZ.jpg  ...
#
#                                  production_countries release_date  \
# 0                                                 NaN          NaN
# 1   [{'iso_3166_1': 'US', 'name': 'United States o...   2019-04-24
# 2   [{'iso_3166_1': 'US', 'name': 'United States o...   2009-12-15
# 3   [{'iso_3166_1': 'US', 'name': 'United States o...   2015-12-15
# 4   [{'iso_3166_1': 'US', 'name': 'United States o...   2018-04-25
# 5   [{'iso_3166_1': 'US', 'name': 'United States o...   1997-11-18
# 6   [{'iso_3166_1': 'US', 'name': 'United States o...   2015-06-06
# 7   [{'iso_3166_1': 'US', 'name': 'United States o...   2019-07-12
# 8   [{'iso_3166_1': 'US', 'name': 'United States o...   2012-04-25
# 9   [{'iso_3166_1': 'US', 'name': 'United States o...   2015-04-01
# 10  [{'iso_3166_1': 'US', 'name': 'United States o...   2015-04-22
# 11  [{'iso_3166_1': 'US', 'name': 'United States o...   2018-02-13
# 12  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...   2011-07-12
# 13  [{'iso_3166_1': 'US', 'name': 'United States o...   2017-12-13
# 14  [{'iso_3166_1': 'US', 'name': 'United States o...   2019-11-20
# 15  [{'iso_3166_1': 'US', 'name': 'United States o...   2018-06-06
# 16  [{'iso_3166_1': 'US', 'name': 'United States o...   2013-11-20
# 17  [{'iso_3166_1': 'US', 'name': 'United States o...   2017-03-16
# 18  [{'iso_3166_1': 'US', 'name': 'United States o...   2018-06-14
#
#          revenue  runtime                                   spoken_languages  \
# 0            NaN      NaN                                                NaN
# 1   2.799439e+09    181.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2   2.923706e+09    162.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3   2.068224e+09    136.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4   2.052415e+09    149.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 5   2.264162e+09    194.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 6   1.671537e+09    124.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 7   1.662021e+09    118.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 8   1.518816e+09    143.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 9   1.515400e+09    139.0  [{'english_name': 'Arabic', 'iso_639_1': 'ar',...
# 10  1.405404e+09    141.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 11  1.349926e+09    135.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 12  1.341511e+09    130.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 13  1.332699e+09    152.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 14  1.453683e+09    103.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 15  1.310469e+09    129.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 16  1.274219e+09    102.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 17  1.266116e+09    129.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 18  1.243226e+09    118.0  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#       status                                            tagline  \
# 0        NaN                                                NaN
# 1   Released                                 Avenge the fallen.
# 2   Released                        Enter the world of Pandora.
# 3   Released                      Every generation has a story.
# 4   Released                      Destiny arrives all the same.
# 5   Released          Nothing on earth could come between them.
# 6   Released                                  The park is open.
# 7   Released                             The king has returned.
# 8   Released                            Some assembly required.
# 9   Released                               Vengeance hits home.
# 10  Released                                A new age has come.
# 11  Released                                Long live the king.
# 12  Released                                       It all ends.
# 13  Released                                   Let the Past Die
# 14  Released                     The past is not what it seems.
# 15  Released                                  The park is gone.
# 16  Released  Who will save the day? The ice guy? The nice g...
# 17  Released                                      Be our guest.
# 18  Released                      It's been too long, dahlings.
#
#                                            title vote_average  vote_count
# 0                                            NaN          NaN         NaN
# 1                              Avengers: Endgame        8.238     26959.0
# 2                                         Avatar        7.594     32853.0
# 3                   Star Wars: The Force Awakens        7.300     20103.0
# 4                         Avengers: Infinity War        8.236     31176.0
# 5                                        Titanic        7.903     26511.0
# 6                                 Jurassic World        6.700     21120.0
# 7                                  The Lion King        7.103     10569.0
# 8                                   The Avengers        7.865     34215.0
# 9                                      Furious 7        7.223     11030.0
# 10                       Avengers: Age of Ultron        7.300     23875.0
# 11                                 Black Panther        7.366     22970.0
# 12  Harry Potter and the Deathly Hallows: Part 2        8.084     21450.0
# 13                      Star Wars: The Last Jedi        6.800     15926.0
# 14                                     Frozen II        7.241     10071.0
# 15                Jurassic World: Fallen Kingdom        6.538     12408.0
# 16                                        Frozen        7.249     17182.0
# 17                          Beauty and the Beast        6.969     15831.0
# 18                                 Incredibles 2        7.456     13366.0
#
# [19 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['backdrop_path', 'belongs_to_collection', 'budget', 'genres', 'id',
#        'origin_country', 'original_language', 'overview', 'popularity',
#        'poster_path', 'production_companies', 'production_countries',
#        'release_date', 'revenue', 'runtime', 'spoken_languages', 'status',
#        'tagline', 'title', 'vote_average', 'vote_count'],
#       dtype='object')

# %% [markdown]
# ## Evaluate JSON-like columns

# %%
categorical_columns = ['belongs_to_collection', 'genres', 'production_countries', 'production_companies', 'spoken_languages', 'origin_country']

# %%
df[categorical_columns].head(5)
# Out:
#      belongs_to_collection                                    genres  \
# 0                      NaN                                       NaN
# 1  The Avengers Collection          Adventure|Science Fiction|Action
# 2        Avatar Collection  Action|Adventure|Fantasy|Science Fiction
# 3     Star Wars Collection          Adventure|Action|Science Fiction
# 4  The Avengers Collection          Adventure|Action|Science Fiction
#
#                       production_countries  \
# 0                                      NaN
# 1                 United States of America
# 2  United States of America|United Kingdom
# 3                 United States of America
# 4                 United States of America
#
#                                 production_companies        spoken_languages  \
# 0                                                NaN                     NaN
# 1                                     Marvel Studios  English|Japanese|Xhosa
# 2  Dune Entertainment|Lightstorm Entertainment|20...         English|Spanish
# 3                           Lucasfilm Ltd.|Bad Robot                 English
# 4                                     Marvel Studios           English|Xhosa
#
#   origin_country
# 0            NaN
# 1           [US]
# 2           [US]
# 3           [US]
# 4           [US]

# %% [markdown]
# ## Extracting and cleaning json columns

# %%
df.info
# Out:
# <bound method DataFrame.info of                        backdrop_path                belongs_to_collection  \
# 0                                NaN                                  NaN
# 1   /9wXPKruA6bWYk2co5ix6fH59Qr8.jpg              The Avengers Collection
# 2   /7JNzw1tSZZEgsBw6lu0VfO2X2Ef.jpg                    Avatar Collection
# 3   /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg                 Star Wars Collection
# 4   /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg              The Avengers Collection
# 5   /xnHVX37XZEp33hhCbYlQFq7ux1J.jpg                                  NaN
# 6   /dF6FjTZzRTENfB4R17HDN20jLT2.jpg             Jurassic Park Collection
# 7   /1TUg5pO1VZ4B0Q1amk3OlXvlpXV.jpg    The Lion King (Reboot) Collection
# 8   /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg              The Avengers Collection
# 9   /ehzI1mVcnHqB58NqPyQwpMqcVoz.jpg  The Fast and the Furious Collection
# 10  /kIBK5SKwgqIIuRKhhWrJn3XkbPq.jpg              The Avengers Collection
# 11  /b6ZJZHUdMEFECvGiDpJjlfUWela.jpg             Black Panther Collection
# 12  /n5A7brJCjejceZmHyujwUTVgQNC.jpg              Harry Potter Collection
# 13  /5Iw7zQTHVRBOYpA0V6z0yypOPZh.jpg                 Star Wars Collection
# 14  /AoSZyb37ljMAxw0RdeQEBHKtgcc.jpg                    Frozen Collection
# 15  /gBmrsugfWpiXRh13Vo3j0WW55qD.jpg             Jurassic Park Collection
# 16  /u2bZhH3nTf0So0UIC1QxAqBvC07.jpg                    Frozen Collection
# 17  /uU1Mt4JWhDvl4vKb3AfxNsorkoM.jpg                                  NaN
# 18  /mabuNsGJgRuCTuGqjFkWe1xdu19.jpg           The Incredibles Collection
#
#     budget                                     genres        id  \
# 0      NaN                                        NaN       NaN
# 1    356.0           Adventure|Science Fiction|Action  299534.0
# 2    237.0   Action|Adventure|Fantasy|Science Fiction   19995.0
# 3    245.0           Adventure|Action|Science Fiction  140607.0
# 4    300.0           Adventure|Action|Science Fiction  299536.0
# 5    200.0                              Drama|Romance     597.0
# 6    150.0  Action|Adventure|Science Fiction|Thriller  135397.0
# 7    260.0           Adventure|Drama|Family|Animation  420818.0
# 8    220.0           Science Fiction|Action|Adventure   24428.0
# 9    190.0                      Action|Crime|Thriller  168259.0
# 10   235.0           Action|Adventure|Science Fiction   99861.0
# 11   200.0           Action|Adventure|Science Fiction  284054.0
# 12   125.0                          Adventure|Fantasy   12445.0
# 13   300.0           Adventure|Action|Science Fiction  181808.0
# 14   150.0  Family|Animation|Adventure|Comedy|Fantasy  330457.0
# 15   170.0  Action|Adventure|Science Fiction|Thriller  351286.0
# 16   150.0         Animation|Family|Adventure|Fantasy  109445.0
# 17   160.0                     Family|Fantasy|Romance  321612.0
# 18   200.0          Action|Adventure|Animation|Family  260513.0
#
#    origin_country original_language  \
# 0             NaN               NaN
# 1            [US]                en
# 2            [US]                en
# 3            [US]                en
# 4            [US]                en
# 5            [US]                en
# 6            [US]                en
# 7            [US]                en
# 8            [US]                en
# 9            [US]                en
# 10           [US]                en
# 11           [US]                en
# 12           [GB]                en
# 13           [US]                en
# 14           [US]                en
# 15           [US]                en
# 16           [US]                en
# 17           [US]                en
# 18           [US]                en
#
#                                              overview  popularity  \
# 0                                                 NaN         NaN
# 1   After the devastating events of Avengers: Infi...     13.7085
# 2   In the 22nd century, a paraplegic Marine is di...     24.2976
# 3   Thirty years after defeating the Galactic Empi...      7.8068
# 4   As the Avengers and their allies have continue...     22.2327
# 5   101-year-old Rose DeWitt Bukater tells the sto...     28.7753
# 6   Twenty-two years after the events of Jurassic ...      9.5096
# 7   Simba idolizes his father, King Mufasa, and ta...      9.0748
# 8   When an unexpected enemy emerges and threatens...     45.5917
# 9   Deckard Shaw seeks revenge against Dominic Tor...      8.6750
# 10  When Tony Stark tries to jumpstart a dormant p...     10.5454
# 11  King T'Challa returns home to the reclusive, t...      8.6974
# 12  Harry, Ron and Hermione continue their quest t...     16.6485
# 13  Rey develops her newly discovered abilities wi...      6.9144
# 14  Elsa, Anna, Kristoff and Olaf head far into th...     10.0343
# 15  Three years after Jurassic World was destroyed...      9.2901
# 16  Young princess Anna of Arendelle dreams about ...     20.4260
# 17  A live-action adaptation of Disney's version o...     11.9931
# 18  Elastigirl springs into action to save the day...     10.7522
#
#                          poster_path  ...  \
# 0                                NaN  ...
# 1   /bR8ISy1O9XQxqiy0fQFw2BX72RQ.jpg  ...
# 2   /gKY6q7SjCkAU6FqvqWybDYgUKIF.jpg  ...
# 3   /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg  ...
# 4   /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg  ...
# 5   /9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg  ...
# 6   /rhr4y79GpxQF9IsfJItRXVaoGs4.jpg  ...
# 7   /dzBtMocZuJbjLOXvrl4zGYigDzh.jpg  ...
# 8    /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg  ...
# 9   /ktofZ9Htrjiy0P6LEowsDaxd3Ri.jpg  ...
# 10  /4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg  ...
# 11  /uxzzxijgPIY7slzFvMotPv8wjKA.jpg  ...
# 12  /c54HpQmuwXjHq2C9wmoACjxoom3.jpg  ...
# 13  /kOVEVeg59E0wsnXmF9nrh6OmWII.jpg  ...
# 14  /mINJaa34MtknCYl5AjtNJzWj8cD.jpg  ...
# 15  /x8cLgs0uXlb9rmpuVIxopoRGnCr.jpg  ...
# 16  /itAKcobTYGpYT8Phwjd8c9hleTo.jpg  ...
# 17  /hKegSKIDep2ewJWPUQD7u0KqFIp.jpg  ...
# 18  /9lFKBtaVIhP7E2Pk0IY1CwTKTMZ.jpg  ...
#
#                        production_countries release_date   revenue  runtime  \
# 0                                       NaN          NaT       NaN      NaN
# 1                  United States of America   2019-04-24  0.000356    181.0
# 2   United States of America|United Kingdom   2009-12-15  0.000237    162.0
# 3                  United States of America   2015-12-15  0.000245    136.0
# 4                  United States of America   2018-04-25  0.000300    149.0
# 5                  United States of America   1997-11-18  0.000200    194.0
# 6                  United States of America   2015-06-06  0.000150    124.0
# 7                  United States of America   2019-07-12  0.000260    118.0
# 8                  United States of America   2012-04-25  0.000220    143.0
# 9                  United States of America   2015-04-01  0.000190    139.0
# 10                 United States of America   2015-04-22  0.000235    141.0
# 11                 United States of America   2018-02-13  0.000200    135.0
# 12  United Kingdom|United States of America   2011-07-12  0.000125    130.0
# 13                 United States of America   2017-12-13  0.000300    152.0
# 14                 United States of America   2019-11-20  0.000150    103.0
# 15                 United States of America   2018-06-06  0.000170    129.0
# 16                 United States of America   2013-11-20  0.000150    102.0
# 17                 United States of America   2017-03-16  0.000160    129.0
# 18                 United States of America   2018-06-14  0.000200    118.0
#
#                                  spoken_languages    status  \
# 0                                             NaN       NaN
# 1                          English|Japanese|Xhosa  Released
# 2                                 English|Spanish  Released
# 3                                         English  Released
# 4                                   English|Xhosa  Released
# 5   English|French|German|Swedish|Italian|Russian  Released
# 6                                         English  Released
# 7                                         English  Released
# 8                           English|Hindi|Russian  Released
# 9                     Arabic|English|Spanish|Thai  Released
# 10                                        English  Released
# 11                   English|Korean|Swahili|Xhosa  Released
# 12                                        English  Released
# 13                                        English  Released
# 14                                        English  Released
# 15                                English|Russian  Released
# 16                                        English  Released
# 17                                 English|French  Released
# 18                                        English  Released
#
#                                               tagline  \
# 0                                                 NaN
# 1                                  Avenge the fallen.
# 2                         Enter the world of Pandora.
# 3                       Every generation has a story.
# 4                       Destiny arrives all the same.
# 5           Nothing on earth could come between them.
# 6                                   The park is open.
# 7                              The king has returned.
# 8                             Some assembly required.
# 9                                Vengeance hits home.
# 10                                A new age has come.
# 11                                Long live the king.
# 12                                       It all ends.
# 13                                   Let the Past Die
# 14                     The past is not what it seems.
# 15                                  The park is gone.
# 16  Who will save the day? The ice guy? The nice g...
# 17                                      Be our guest.
# 18                      It's been too long, dahlings.
#
#                                            title vote_average  vote_count
# 0                                            NaN          NaN         NaN
# 1                              Avengers: Endgame        8.238     26959.0
# 2                                         Avatar        7.594     32853.0
# 3                   Star Wars: The Force Awakens        7.300     20103.0
# 4                         Avengers: Infinity War        8.236     31176.0
# 5                                        Titanic        7.903     26511.0
# 6                                 Jurassic World        6.700     21120.0
# 7                                  The Lion King        7.103     10569.0
# 8                                   The Avengers        7.865     34215.0
# 9                                      Furious 7        7.223     11030.0
# 10                       Avengers: Age of Ultron        7.300     23875.0
# 11                                 Black Panther        7.366     22970.0
# 12  Harry Potter and the Deathly Hallows: Part 2        8.084     21450.0
# 13                      Star Wars: The Last Jedi        6.800     15926.0
# 14                                     Frozen II        7.241     10071.0
# 15                Jurassic World: Fallen Kingdom        6.538     12408.0
# 16                                        Frozen        7.249     17182.0
# 17                          Beauty and the Beast        6.969     15831.0
# 18                                 Incredibles 2        7.456     13366.0
#
# [19 rows x 21 columns]>

# %%
df = clean_movie_data(df)

# %%
df
# Out:
#                        backdrop_path                belongs_to_collection  \
# 0                                NaN                                  NaN
# 1   /9wXPKruA6bWYk2co5ix6fH59Qr8.jpg              The Avengers Collection
# 2   /7JNzw1tSZZEgsBw6lu0VfO2X2Ef.jpg                    Avatar Collection
# 3   /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg                 Star Wars Collection
# 4   /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg              The Avengers Collection
# 5   /xnHVX37XZEp33hhCbYlQFq7ux1J.jpg                                  NaN
# 6   /dF6FjTZzRTENfB4R17HDN20jLT2.jpg             Jurassic Park Collection
# 7   /1TUg5pO1VZ4B0Q1amk3OlXvlpXV.jpg    The Lion King (Reboot) Collection
# 8   /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg              The Avengers Collection
# 9   /ehzI1mVcnHqB58NqPyQwpMqcVoz.jpg  The Fast and the Furious Collection
# 10  /kIBK5SKwgqIIuRKhhWrJn3XkbPq.jpg              The Avengers Collection
# 11  /b6ZJZHUdMEFECvGiDpJjlfUWela.jpg             Black Panther Collection
# 12  /n5A7brJCjejceZmHyujwUTVgQNC.jpg              Harry Potter Collection
# 13  /5Iw7zQTHVRBOYpA0V6z0yypOPZh.jpg                 Star Wars Collection
# 14  /AoSZyb37ljMAxw0RdeQEBHKtgcc.jpg                    Frozen Collection
# 15  /gBmrsugfWpiXRh13Vo3j0WW55qD.jpg             Jurassic Park Collection
# 16  /u2bZhH3nTf0So0UIC1QxAqBvC07.jpg                    Frozen Collection
# 17  /uU1Mt4JWhDvl4vKb3AfxNsorkoM.jpg                                  NaN
# 18  /mabuNsGJgRuCTuGqjFkWe1xdu19.jpg           The Incredibles Collection
#
#          budget                                     genres        id  \
# 0           NaN                                        NaN       NaN
# 1   356000000.0           Adventure|Science Fiction|Action  299534.0
# 2   237000000.0   Action|Adventure|Fantasy|Science Fiction   19995.0
# 3   245000000.0           Adventure|Action|Science Fiction  140607.0
# 4   300000000.0           Adventure|Action|Science Fiction  299536.0
# 5   200000000.0                              Drama|Romance     597.0
# 6   150000000.0  Action|Adventure|Science Fiction|Thriller  135397.0
# 7   260000000.0           Adventure|Drama|Family|Animation  420818.0
# 8   220000000.0           Science Fiction|Action|Adventure   24428.0
# 9   190000000.0                      Action|Crime|Thriller  168259.0
# 10  235000000.0           Action|Adventure|Science Fiction   99861.0
# 11  200000000.0           Action|Adventure|Science Fiction  284054.0
# 12  125000000.0                          Adventure|Fantasy   12445.0
# 13  300000000.0           Adventure|Action|Science Fiction  181808.0
# 14  150000000.0  Family|Animation|Adventure|Comedy|Fantasy  330457.0
# 15  170000000.0  Action|Adventure|Science Fiction|Thriller  351286.0
# 16  150000000.0         Animation|Family|Adventure|Fantasy  109445.0
# 17  160000000.0                     Family|Fantasy|Romance  321612.0
# 18  200000000.0          Action|Adventure|Animation|Family  260513.0
#
#    origin_country original_language  \
# 0             NaN               NaN
# 1            [US]                en
# 2            [US]                en
# 3            [US]                en
# 4            [US]                en
# 5            [US]                en
# 6            [US]                en
# 7            [US]                en
# 8            [US]                en
# 9            [US]                en
# 10           [US]                en
# 11           [US]                en
# 12           [GB]                en
# 13           [US]                en
# 14           [US]                en
# 15           [US]                en
# 16           [US]                en
# 17           [US]                en
# 18           [US]                en
#
#                                              overview  popularity  \
# 0                                                 NaN         NaN
# 1   After the devastating events of Avengers: Infi...     13.7085
# 2   In the 22nd century, a paraplegic Marine is di...     24.2976
# 3   Thirty years after defeating the Galactic Empi...      7.8068
# 4   As the Avengers and their allies have continue...     22.2327
# 5   101-year-old Rose DeWitt Bukater tells the sto...     28.7753
# 6   Twenty-two years after the events of Jurassic ...      9.5096
# 7   Simba idolizes his father, King Mufasa, and ta...      9.0748
# 8   When an unexpected enemy emerges and threatens...     45.5917
# 9   Deckard Shaw seeks revenge against Dominic Tor...      8.6750
# 10  When Tony Stark tries to jumpstart a dormant p...     10.5454
# 11  King T'Challa returns home to the reclusive, t...      8.6974
# 12  Harry, Ron and Hermione continue their quest t...     16.6485
# 13  Rey develops her newly discovered abilities wi...      6.9144
# 14  Elsa, Anna, Kristoff and Olaf head far into th...     10.0343
# 15  Three years after Jurassic World was destroyed...      9.2901
# 16  Young princess Anna of Arendelle dreams about ...     20.4260
# 17  A live-action adaptation of Disney's version o...     11.9931
# 18  Elastigirl springs into action to save the day...     10.7522
#
#                          poster_path  ...  \
# 0                                NaN  ...
# 1   /bR8ISy1O9XQxqiy0fQFw2BX72RQ.jpg  ...
# 2   /gKY6q7SjCkAU6FqvqWybDYgUKIF.jpg  ...
# 3   /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg  ...
# 4   /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg  ...
# 5   /9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg  ...
# 6   /rhr4y79GpxQF9IsfJItRXVaoGs4.jpg  ...
# 7   /dzBtMocZuJbjLOXvrl4zGYigDzh.jpg  ...
# 8    /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg  ...
# 9   /ktofZ9Htrjiy0P6LEowsDaxd3Ri.jpg  ...
# 10  /4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg  ...
# 11  /uxzzxijgPIY7slzFvMotPv8wjKA.jpg  ...
# 12  /c54HpQmuwXjHq2C9wmoACjxoom3.jpg  ...
# 13  /kOVEVeg59E0wsnXmF9nrh6OmWII.jpg  ...
# 14  /mINJaa34MtknCYl5AjtNJzWj8cD.jpg  ...
# 15  /x8cLgs0uXlb9rmpuVIxopoRGnCr.jpg  ...
# 16  /itAKcobTYGpYT8Phwjd8c9hleTo.jpg  ...
# 17  /hKegSKIDep2ewJWPUQD7u0KqFIp.jpg  ...
# 18  /9lFKBtaVIhP7E2Pk0IY1CwTKTMZ.jpg  ...
#
#                        production_countries release_date       revenue  \
# 0                                       NaN          NaT           NaN
# 1                  United States of America   2019-04-24  2.799439e+09
# 2   United States of America|United Kingdom   2009-12-15  2.923706e+09
# 3                  United States of America   2015-12-15  2.068224e+09
# 4                  United States of America   2018-04-25  2.052415e+09
# 5                  United States of America   1997-11-18  2.264162e+09
# 6                  United States of America   2015-06-06  1.671537e+09
# 7                  United States of America   2019-07-12  1.662021e+09
# 8                  United States of America   2012-04-25  1.518816e+09
# 9                  United States of America   2015-04-01  1.515400e+09
# 10                 United States of America   2015-04-22  1.405404e+09
# 11                 United States of America   2018-02-13  1.349926e+09
# 12  United Kingdom|United States of America   2011-07-12  1.341511e+09
# 13                 United States of America   2017-12-13  1.332699e+09
# 14                 United States of America   2019-11-20  1.453683e+09
# 15                 United States of America   2018-06-06  1.310469e+09
# 16                 United States of America   2013-11-20  1.274219e+09
# 17                 United States of America   2017-03-16  1.266116e+09
# 18                 United States of America   2018-06-14  1.243226e+09
#
#     runtime                               spoken_languages    status  \
# 0       NaN                                            NaN       NaN
# 1     181.0                         English|Japanese|Xhosa  Released
# 2     162.0                                English|Spanish  Released
# 3     136.0                                        English  Released
# 4     149.0                                  English|Xhosa  Released
# 5     194.0  English|French|German|Swedish|Italian|Russian  Released
# 6     124.0                                        English  Released
# 7     118.0                                        English  Released
# 8     143.0                          English|Hindi|Russian  Released
# 9     139.0                    Arabic|English|Spanish|Thai  Released
# 10    141.0                                        English  Released
# 11    135.0                   English|Korean|Swahili|Xhosa  Released
# 12    130.0                                        English  Released
# 13    152.0                                        English  Released
# 14    103.0                                        English  Released
# 15    129.0                                English|Russian  Released
# 16    102.0                                        English  Released
# 17    129.0                                 English|French  Released
# 18    118.0                                        English  Released
#
#                                               tagline  \
# 0                                                 NaN
# 1                                  Avenge the fallen.
# 2                         Enter the world of Pandora.
# 3                       Every generation has a story.
# 4                       Destiny arrives all the same.
# 5           Nothing on earth could come between them.
# 6                                   The park is open.
# 7                              The king has returned.
# 8                             Some assembly required.
# 9                                Vengeance hits home.
# 10                                A new age has come.
# 11                                Long live the king.
# 12                                       It all ends.
# 13                                   Let the Past Die
# 14                     The past is not what it seems.
# 15                                  The park is gone.
# 16  Who will save the day? The ice guy? The nice g...
# 17                                      Be our guest.
# 18                      It's been too long, dahlings.
#
#                                            title vote_average  vote_count
# 0                                            NaN          NaN         NaN
# 1                              Avengers: Endgame        8.238     26959.0
# 2                                         Avatar        7.594     32853.0
# 3                   Star Wars: The Force Awakens        7.300     20103.0
# 4                         Avengers: Infinity War        8.236     31176.0
# 5                                        Titanic        7.903     26511.0
# 6                                 Jurassic World        6.700     21120.0
# 7                                  The Lion King        7.103     10569.0
# 8                                   The Avengers        7.865     34215.0
# 9                                      Furious 7        7.223     11030.0
# 10                       Avengers: Age of Ultron        7.300     23875.0
# 11                                 Black Panther        7.366     22970.0
# 12  Harry Potter and the Deathly Hallows: Part 2        8.084     21450.0
# 13                      Star Wars: The Last Jedi        6.800     15926.0
# 14                                     Frozen II        7.241     10071.0
# 15                Jurassic World: Fallen Kingdom        6.538     12408.0
# 16                                        Frozen        7.249     17182.0
# 17                          Beauty and the Beast        6.969     15831.0
# 18                                 Incredibles 2        7.456     13366.0
#
# [19 rows x 21 columns]

# %%
inspect_categorical_columns_using_value_counts(df,categorical_columns)
# Out:
# Value counts for column: belongs_to_collection
# belongs_to_collection
# The Avengers Collection                4
# NaN                                    3
# Star Wars Collection                   2
# Frozen Collection                      2
# Jurassic Park Collection               2
# Avatar Collection                      1
# The Lion King (Reboot) Collection      1
# The Fast and the Furious Collection    1
# Black Panther Collection               1
# Harry Potter Collection                1
# The Incredibles Collection             1
# Name: count, dtype: int64
#
#
# Value counts for column: genres
# genres
# Adventure|Action|Science Fiction             3
# Action|Adventure|Science Fiction|Thriller    2
# Action|Adventure|Science Fiction             2
# Action|Adventure|Fantasy|Science Fiction     1
# Adventure|Science Fiction|Action             1
# Drama|Romance                                1
# NaN                                          1
# Adventure|Drama|Family|Animation             1
# Science Fiction|Action|Adventure             1
# Action|Crime|Thriller                        1
# Adventure|Fantasy                            1
# Family|Animation|Adventure|Comedy|Fantasy    1
# Animation|Family|Adventure|Fantasy           1
# Family|Fantasy|Romance                       1
# Action|Adventure|Animation|Family            1
# Name: count, dtype: int64
#
#
# Value counts for column: production_countries
# production_countries
# United States of America                   16
# NaN                                         1
# United States of America|United Kingdom     1
# United Kingdom|United States of America     1
# Name: count, dtype: int64
#
#
# Value counts for column: production_companies
# production_companies
# Marvel Studios                                                                          5
# Walt Disney Animation Studios                                                           2
# Dune Entertainment|Lightstorm Entertainment|20th Century Fox|Ingenious Film Partners    1
# Lucasfilm Ltd.|Bad Robot                                                                1
# Paramount Pictures|20th Century Fox|Lightstorm Entertainment                            1
# NaN                                                                                     1
# Amblin Entertainment|Universal Pictures|Legendary Pictures                              1
# Walt Disney Pictures|Fairview Entertainment                                             1
# Warner Bros. Pictures|Heyday Films                                                      1
# Original Film|One Race|Universal Pictures                                               1
# Lucasfilm Ltd.                                                                          1
# Amblin Entertainment|Universal Pictures                                                 1
# Walt Disney Pictures|Mandeville Films                                                   1
# Pixar                                                                                   1
# Name: count, dtype: int64
#
#
# Value counts for column: spoken_languages
# spoken_languages
# English                                          9
# English|Japanese|Xhosa                           1
# NaN                                              1
# English|Spanish                                  1
# English|Xhosa                                    1
# English|French|German|Swedish|Italian|Russian    1
# English|Hindi|Russian                            1
# Arabic|English|Spanish|Thai                      1
# English|Korean|Swahili|Xhosa                     1
# English|Russian                                  1
# English|French                                   1
# Name: count, dtype: int64

# %% [markdown]
# ## Replace unrealistic values

# %%
df = replace_unrealistic_values(df)

# %%
df
# Out:
#                        backdrop_path  belongs_to_collection  budget  genres  \
# 0                                NaN                    NaN     NaN     NaN
# 1   /9wXPKruA6bWYk2co5ix6fH59Qr8.jpg                    NaN   356.0     NaN
# 2   /7JNzw1tSZZEgsBw6lu0VfO2X2Ef.jpg                    NaN   237.0     NaN
# 3   /8BTsTfln4jlQrLXUBquXJ0ASQy9.jpg                    NaN   245.0     NaN
# 4   /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg                    NaN   300.0     NaN
# 5   /xnHVX37XZEp33hhCbYlQFq7ux1J.jpg                    NaN   200.0     NaN
# 6   /dF6FjTZzRTENfB4R17HDN20jLT2.jpg                    NaN   150.0     NaN
# 7   /1TUg5pO1VZ4B0Q1amk3OlXvlpXV.jpg                    NaN   260.0     NaN
# 8   /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg                    NaN   220.0     NaN
# 9   /ehzI1mVcnHqB58NqPyQwpMqcVoz.jpg                    NaN   190.0     NaN
# 10  /kIBK5SKwgqIIuRKhhWrJn3XkbPq.jpg                    NaN   235.0     NaN
# 11  /b6ZJZHUdMEFECvGiDpJjlfUWela.jpg                    NaN   200.0     NaN
# 12  /n5A7brJCjejceZmHyujwUTVgQNC.jpg                    NaN   125.0     NaN
# 13  /5Iw7zQTHVRBOYpA0V6z0yypOPZh.jpg                    NaN   300.0     NaN
# 14  /AoSZyb37ljMAxw0RdeQEBHKtgcc.jpg                    NaN   150.0     NaN
# 15  /gBmrsugfWpiXRh13Vo3j0WW55qD.jpg                    NaN   170.0     NaN
# 16  /u2bZhH3nTf0So0UIC1QxAqBvC07.jpg                    NaN   150.0     NaN
# 17  /uU1Mt4JWhDvl4vKb3AfxNsorkoM.jpg                    NaN   160.0     NaN
# 18  /mabuNsGJgRuCTuGqjFkWe1xdu19.jpg                    NaN   200.0     NaN
#
#           id origin_country original_language  \
# 0        NaN            NaN               NaN
# 1   299534.0           [US]                en
# 2    19995.0           [US]                en
# 3   140607.0           [US]                en
# 4   299536.0           [US]                en
# 5      597.0           [US]                en
# 6   135397.0           [US]                en
# 7   420818.0           [US]                en
# 8    24428.0           [US]                en
# 9   168259.0           [US]                en
# 10   99861.0           [US]                en
# 11  284054.0           [US]                en
# 12   12445.0           [GB]                en
# 13  181808.0           [US]                en
# 14  330457.0           [US]                en
# 15  351286.0           [US]                en
# 16  109445.0           [US]                en
# 17  321612.0           [US]                en
# 18  260513.0           [US]                en
#
#                                              overview  popularity  \
# 0                                                 NaN         NaN
# 1   After the devastating events of Avengers: Infi...     13.7085
# 2   In the 22nd century, a paraplegic Marine is di...     24.2976
# 3   Thirty years after defeating the Galactic Empi...      7.8068
# 4   As the Avengers and their allies have continue...     22.2327
# 5   101-year-old Rose DeWitt Bukater tells the sto...     28.7753
# 6   Twenty-two years after the events of Jurassic ...      9.5096
# 7   Simba idolizes his father, King Mufasa, and ta...      9.0748
# 8   When an unexpected enemy emerges and threatens...     45.5917
# 9   Deckard Shaw seeks revenge against Dominic Tor...      8.6750
# 10  When Tony Stark tries to jumpstart a dormant p...     10.5454
# 11  King T'Challa returns home to the reclusive, t...      8.6974
# 12  Harry, Ron and Hermione continue their quest t...     16.6485
# 13  Rey develops her newly discovered abilities wi...      6.9144
# 14  Elsa, Anna, Kristoff and Olaf head far into th...     10.0343
# 15  Three years after Jurassic World was destroyed...      9.2901
# 16  Young princess Anna of Arendelle dreams about ...     20.4260
# 17  A live-action adaptation of Disney's version o...     11.9931
# 18  Elastigirl springs into action to save the day...     10.7522
#
#                          poster_path  ...  production_countries  release_date  \
# 0                                NaN  ...                   NaN           NaT
# 1   /bR8ISy1O9XQxqiy0fQFw2BX72RQ.jpg  ...                   NaN    2019-04-24
# 2   /gKY6q7SjCkAU6FqvqWybDYgUKIF.jpg  ...                   NaN    2009-12-15
# 3   /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg  ...                   NaN    2015-12-15
# 4   /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg  ...                   NaN    2018-04-25
# 5   /9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg  ...                   NaN    1997-11-18
# 6   /rhr4y79GpxQF9IsfJItRXVaoGs4.jpg  ...                   NaN    2015-06-06
# 7   /dzBtMocZuJbjLOXvrl4zGYigDzh.jpg  ...                   NaN    2019-07-12
# 8    /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg  ...                   NaN    2012-04-25
# 9   /ktofZ9Htrjiy0P6LEowsDaxd3Ri.jpg  ...                   NaN    2015-04-01
# 10  /4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg  ...                   NaN    2015-04-22
# 11  /uxzzxijgPIY7slzFvMotPv8wjKA.jpg  ...                   NaN    2018-02-13
# 12  /c54HpQmuwXjHq2C9wmoACjxoom3.jpg  ...                   NaN    2011-07-12
# 13  /kOVEVeg59E0wsnXmF9nrh6OmWII.jpg  ...                   NaN    2017-12-13
# 14  /mINJaa34MtknCYl5AjtNJzWj8cD.jpg  ...                   NaN    2019-11-20
# 15  /x8cLgs0uXlb9rmpuVIxopoRGnCr.jpg  ...                   NaN    2018-06-06
# 16  /itAKcobTYGpYT8Phwjd8c9hleTo.jpg  ...                   NaN    2013-11-20
# 17  /hKegSKIDep2ewJWPUQD7u0KqFIp.jpg  ...                   NaN    2017-03-16
# 18  /9lFKBtaVIhP7E2Pk0IY1CwTKTMZ.jpg  ...                   NaN    2018-06-14
#
#      revenue  runtime  spoken_languages    status  \
# 0        NaN      NaN               NaN       NaN
# 1   0.000356    181.0               NaN  Released
# 2   0.000237    162.0               NaN  Released
# 3   0.000245    136.0               NaN  Released
# 4   0.000300    149.0               NaN  Released
# 5   0.000200    194.0               NaN  Released
# 6   0.000150    124.0               NaN  Released
# 7   0.000260    118.0               NaN  Released
# 8   0.000220    143.0               NaN  Released
# 9   0.000190    139.0               NaN  Released
# 10  0.000235    141.0               NaN  Released
# 11  0.000200    135.0               NaN  Released
# 12  0.000125    130.0               NaN  Released
# 13  0.000300    152.0               NaN  Released
# 14  0.000150    103.0               NaN  Released
# 15  0.000170    129.0               NaN  Released
# 16  0.000150    102.0               NaN  Released
# 17  0.000160    129.0               NaN  Released
# 18  0.000200    118.0               NaN  Released
#
#                                               tagline  \
# 0                                                 NaN
# 1                                  Avenge the fallen.
# 2                         Enter the world of Pandora.
# 3                       Every generation has a story.
# 4                       Destiny arrives all the same.
# 5           Nothing on earth could come between them.
# 6                                   The park is open.
# 7                              The king has returned.
# 8                             Some assembly required.
# 9                                Vengeance hits home.
# 10                                A new age has come.
# 11                                Long live the king.
# 12                                       It all ends.
# 13                                   Let the Past Die
# 14                     The past is not what it seems.
# 15                                  The park is gone.
# 16  Who will save the day? The ice guy? The nice g...
# 17                                      Be our guest.
# 18                      It's been too long, dahlings.
#
#                                            title vote_average  vote_count
# 0                                            NaN          NaN         NaN
# 1                              Avengers: Endgame        8.238     26959.0
# 2                                         Avatar        7.594     32853.0
# 3                   Star Wars: The Force Awakens        7.300     20103.0
# 4                         Avengers: Infinity War        8.236     31176.0
# 5                                        Titanic        7.903     26511.0
# 6                                 Jurassic World        6.700     21120.0
# 7                                  The Lion King        7.103     10569.0
# 8                                   The Avengers        7.865     34215.0
# 9                                      Furious 7        7.223     11030.0
# 10                       Avengers: Age of Ultron        7.300     23875.0
# 11                                 Black Panther        7.366     22970.0
# 12  Harry Potter and the Deathly Hallows: Part 2        8.084     21450.0
# 13                      Star Wars: The Last Jedi        6.800     15926.0
# 14                                     Frozen II        7.241     10071.0
# 15                Jurassic World: Fallen Kingdom        6.538     12408.0
# 16                                        Frozen        7.249     17182.0
# 17                          Beauty and the Beast        6.969     15831.0
# 18                                 Incredibles 2        7.456     13366.0
#
# [19 rows x 21 columns]

# %% [markdown]
# ## Removing NAN's, dropping duplicates and filtering for released movies only

# %%
df = removing_na_and_duplicates(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 df = removing_na_and_duplicates(df)
#
# File ~\Desktop\Lib\Course Projects\Specialization\scripts\clean_data.py:134, in removing_na_and_duplicates(df)
#     132 def removing_na_and_duplicates(df):
#     133     """Applies all NA and duplicate removal steps."""
# --> 134     df = remove_duplicates(df)
#     135     critical_columns = ['title', 'id']
#     136     df = drop_rows_with_na_in_critical_columns(df, critical_columns)
#
# File ~\Desktop\Lib\Course Projects\Specialization\scripts\clean_data.py:116, in remove_duplicates(df)
#     114 if 'id 'in df.columns:
#     115     return df.drop_duplicates(subset=['id'])
# --> 116 return df.drop_duplicates()
#
# File ~\Desktop\Lib\Course Projects\Specialization\movieenv\Lib\site-packages\pandas\core\frame.py:6840, in DataFrame.drop_duplicates(self, subset, keep, inplace, ignore_index)
#    6837 inplace = validate_bool_kwarg(inplace, "inplace")
#    6838 ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
# -> 6840 result = self[-self.duplicated(subset, keep=keep)]
#    6841 if ignore_index:
#    6842     result.index = default_index(len(result))
#
# File ~\Desktop\Lib\Course Projects\Specialization\movieenv\Lib\site-packages\pandas\core\frame.py:6980, in DataFrame.duplicated(self, subset, keep)
#    6978 else:
#    6979     vals = (col.values for name, col in self.items() if name in subset)
# -> 6980     labels, shape = map(list, zip(*map(f, vals)))
#    6982     ids = get_group_index(labels, tuple(shape), sort=False, xnull=False)
#    6983     result = self._constructor_sliced(duplicated(ids, keep), index=self.index)
#
# File ~\Desktop\Lib\Course Projects\Specialization\movieenv\Lib\site-packages\pandas\core\frame.py:6948, in DataFrame.duplicated.<locals>.f(vals)
#    6947 def f(vals) -> tuple[np.ndarray, int]:
# -> 6948     labels, shape = algorithms.factorize(vals, size_hint=len(self))
#    6949     return labels.astype("i8", copy=False), len(shape)
#
# File ~\Desktop\Lib\Course Projects\Specialization\movieenv\Lib\site-packages\pandas\core\algorithms.py:795, in factorize(values, sort, use_na_sentinel, size_hint)
#     792             # Don't modify (potentially user-provided) array
#     793             values = np.where(null_mask, na_value, values)
# --> 795     codes, uniques = factorize_array(
#     796         values,
#     797         use_na_sentinel=use_na_sentinel,
#     798         size_hint=size_hint,
#     799     )
#     801 if sort and len(uniques) > 0:
#     802     uniques, codes = safe_sort(
#     803         uniques,
#     804         codes,
#    (...)    807         verify=False,
#     808     )
#
# File ~\Desktop\Lib\Course Projects\Specialization\movieenv\Lib\site-packages\pandas\core\algorithms.py:595, in factorize_array(values, use_na_sentinel, size_hint, na_value, mask)
#     592 hash_klass, values = _get_hashtable_algo(values)
#     594 table = hash_klass(size_hint or len(values))
# --> 595 uniques, codes = table.factorize(
#     596     values,
#     597     na_sentinel=-1,
#     598     na_value=na_value,
#     599     mask=mask,
#     600     ignore_na=use_na_sentinel,
#     601 )
#     603 # re-cast e.g. i8->dt64/td64, uint8->bool
#     604 uniques = _reconstruct_data(uniques, original.dtype, original)
#
# File pandas/_libs/hashtable_class_helper.pxi:7293, in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# File pandas/_libs/hashtable_class_helper.pxi:7203, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'
